# %%
print("hello world")
# Out:
# hello world

# %%
pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (2.137.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (2.32.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (2.19.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.63.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (5.27.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.24.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from googleapiclient.discovery import build

# %%
"AIzaSyCggW6z0SfllsuOWWlbCnDych4SbR_SImg"
# Out:
# 'AIzaSyCggW6z0SfllsuOWWlbCnDych4SbR_SImg'

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (4.8.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from pymongo) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (2.9.9)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
#api key connection

def Api_connect():
    Api_Id="AIzaSyCggW6z0SfllsuOWWlbCnDych4SbR_SImg"

    api_service_name="youtube"
    api_version="v3"

    youtube=build(api_service_name,api_version,developerKey=Api_Id)

    return youtube

youtube=Api_connect()

# %%
#get channels information
def get_channels_info(channel_id):
        request=youtube.channels().list(
                         part="snippet,ContentDetails,statistics",
                         id=channel_id
        )
        response=request.execute()

        for i in response["items"]:
            data=dict(Channel_Name=i["snippet"]['title'],
                    Channel_Id=i["id"],
                    SubscriberCount=i['statistics']['subscriberCount'],
                    Views=i["statistics"]["viewCount"],
                    Total_videos=i["statistics"]["videoCount"],
                    Channal_Description=i["snippet"]["description"],
                    Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
        return data

# %%
Channel_details=get_channels_info("UC00qEBA94D-vjRsvX6_EaVQ")

# %%
Channel_details
# Out:
# {'Channel_Name': 'tts shalini.s',
#  'Channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#  'SubscriberCount': '736',
#  'Views': '30483',
#  'Total_videos': '75',
#  'Channal_Description': 'Tts_shalini_army \nSubscribe 💕 share💙\n',
#  'Playlist_Id': 'UU00qEBA94D-vjRsvX6_EaVQ'}

# %%
#get video ids
def get_videos_ids(channel_id):
    video_ids=[]
    response=youtube.channels().list(id=channel_id,
                                    part='contentDetails').execute()
    playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None

    while True:

        response1=youtube.playlistItems().list(
                                            part='snippet',
                                            playlistId=playlist_Id,
                                            maxResults=50,
                                            pageToken=next_page_token).execute()
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')

        if next_page_token is None:
            break
    return video_ids

# %%
video_ids=get_videos_ids('UC00qEBA94D-vjRsvX6_EaVQ')

# %%
len(video_ids)
# Out:
# 76

# %%
video_ids
# Out:
# ['EU0apbqE0ZI',
#  '29_HuFSxDZw',
#  'WNEfiubIoZs',
#  'NJyNgwCWOO8',
#  '2NP7wOiRF4k',
#  '_VyZ7FPm8Ng',
#  'hjYgAMhppoA',
#  'uBCY2KG2dQ8',
#  's92AXjtju30',
#  'fFWN2WUcLak',
#  'p4oepfa4bpc',
#  '-Ae1VD4LRw0',
#  'DMcCQ86G9yc',
#  'Q_76HcWNGU0',
#  '2m9k3fiQKR8',
#  '_234uADpyuI',
#  'RKw8Hq6o-m8',
#  'ccF3J0WZulU',
#  '8TjazwFx4Fg',
#  'Jd18lzoCd7g',
#  'qg4gMRMeW6Y',
#  'RdNMW1qT0Mw',
#  'h1Zg6XJhkTY',
#  'YdpTdkR0058',
#  'KpsxEc9z7zY',
#  'PuYHNPXfAzE',
#  'EOHks3AujiY',
#  'sx4KmcW7CHQ',
#  'jQdTxb25Z_M',
#  'vuwdkK5YElc',
#  'IX6Zug8csqI',
#  'q1WsyW0qkIM',
#  'wqSCErGY0Xo',
#  '1PTTU8Sxu6I',
#  '_PtqGM0D3t0',
#  'WGEBkUIMk2Q',
#  'VnRjeXlbnco',
#  '8GeHrp2DEk8',
#  '4X3sDVeSYbk',
#  'EB7wher7ELU',
#  'feaxXs8WHTc',
#  '27N3JzhFfcg',
#  'nQTJRemF6WA',
#  'egtcXu06548',
#  '1hCjeL4sm48',
#  'mSt01AW8Qt0',
#  'KEZ2byQ5gyU',
#  'vxsC_gN7RlE',
#  'CskSmzf_lwY',
#  'kLecrkt9HI0',
#  'bwuakhInT04',
#  'sbfOAnwiyZQ',
#  'Tai5CxL1rlI',
#  'BZIuXUfZYuw',
#  '1lc0AI-JlZ8',
#  'QiU6-45fgVo',
#  'JXiurQjhadI',
#  'EjaFU20XQB8',
#  'N3FycwG2NGc',
#  'XvdDLsgXEJE',
#  'U-ukGmw9asM',
#  'Tk9FGURHs3U',
#  'yWq7N8Lj-Ho',
#  '426k39xf0Ww',
#  'c7vZpGpV8LI',
#  'QubLlmm9vbM',
#  'bjAwdmrvEEw',
#  'pp9XxuqpRWE',
#  'XAdTfnSzgOo',
#  'aWikI9yNhv4',
#  'r0C1Tk0hpIc',
#  '17b7n-YZlNo',
#  'iFwUPIxdAok',
#  'GbW4chZgQPo',
#  'daLflzYevpI',
#  '4wFVdvDKpkc']

# %%
#tts shalini:"UC00qEBA94D-vjRsvX6_EaVQ"
#clara kitchen:"UCLKUZXgKWgN7zWuEHrPeYKA"
#:UC-LsQ1mtWxW1qGrcXhdyQWg'

# %%
video_ids=get_videos_ids("UC00qEBA94D-vjRsvX6_EaVQ")

# %%
len(video_ids)
# Out:
# 76

# %%
#get video information
def get_video_info(video_ids):
        Video_data=[]
        for video_id in video_ids:
                request=youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id                
                
                )
                response=request.execute()
                

                for item in response["items"]:
                        data=dict(channel_Name=item['snippet']['channelTitle'],
                                channel_Id=item['snippet']['channelId'],
                                video_id=item['id'],
                                Title=item['snippet']['title'],
                                Tags=item['snippet'].get('tags'),
                                Thumbnail=item['snippet']['thumbnails']['default']['url'],
                                Description=item['snippet'].get('description'),
                                published_Datee=item['snippet']['publishedAt'],
                                Duration=item['contentDetails']['duration'],
                                Views=item['statistics'].get('viewCount'),
                                Likes=item['statistics'].get('likeCount'),
                                Comments=item['statistics'].get('commentCount'),
                                Favorite_Count=item['statistics']['favoriteCount'],
                                Definition=item['contentDetails']['definition'],
                                Caption_Status=item['contentDetails']['caption'],
                                )
                        Video_data.append(data)
        return Video_data

# %%
get_video_info(video_ids)
# Out:
# [{'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'EU0apbqE0ZI',
#   'Title': 'couple 🥰shorts video',
#   'Tags': ['#kiss', '#hug', '#tts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/EU0apbqE0ZI/default.jpg',
#   'Description': '',
#   'published_Datee': '2023-04-15T09:53:50Z',
#   'Duration': 'PT11S',
#   'Views': '388',
#   'Likes': '76',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '29_HuFSxDZw',
#   'Title': 'tts_shalini.s 😍😍🥰🥰#whatsappstatus',
#   'Tags': ['#food', '#ttf', '#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/29_HuFSxDZw/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-12-19T11:30:01Z',
#   'Duration': 'PT15S',
#   'Views': '1098',
#   'Likes': '168',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'WNEfiubIoZs',
#   'Title': 'tts_shalini #whatsappstatus #short #foodreview',
#   'Tags': ['#road food', '#road foot', '#streetfood'],
#   'Thumbnail': 'https://i.ytimg.com/vi/WNEfiubIoZs/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-11-20T11:30:08Z',
#   'Duration': 'PT15S',
#   'Views': '936',
#   'Likes': '207',
#   'Comments': '19',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'NJyNgwCWOO8',
#   'Title': '#shalini #shorts💋💚⚡',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/NJyNgwCWOO8/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-11-07T16:58:44Z',
#   'Duration': 'PT15S',
#   'Views': '877',
#   'Likes': '178',
#   'Comments': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '2NP7wOiRF4k',
#   'Title': 'My Favourite Reels Collection like 😍🥰| | TTS Shalini Army #trendingnow',
#   'Tags': ['#tamilsong', '#tts_shalini_army'],
#   'Thumbnail': 'https://i.ytimg.com/vi/2NP7wOiRF4k/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-13T06:14:00Z',
#   'Duration': 'PT4M4S',
#   'Views': '388',
#   'Likes': '94',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '_VyZ7FPm8Ng',
#   'Title': '#instalove #loveit #lovely #mylove #loveher #lovehim #u #ilo tts shalini #gpmuthu #biggbosstamil',
#   'Tags': ['#biggbosstamil', '#ttf', '#gpmuthu', '#comedy'],
#   'Thumbnail': 'https://i.ytimg.com/vi/_VyZ7FPm8Ng/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-10T17:59:21Z',
#   'Duration': 'PT15S',
#   'Views': '384',
#   'Likes': '123',
#   'Comments': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'hjYgAMhppoA',
#   'Title': 'Geetha govindam | Hello Yaru | Geetha 🤨#short | TTS Shalini army#vlog#viral#shorts  #trendingshorts',
#   'Tags': ['#shorts', '#viral', '#viral\n\n#vlog'],
#   'Thumbnail': 'https://i.ytimg.com/vi/hjYgAMhppoA/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-09T15:54:53Z',
#   'Duration': 'PT15S',
#   'Views': '590',
#   'Likes': '113',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'uBCY2KG2dQ8',
#   'Title': 'nee sumara tha irukka in💋💕😁 tts shalini #tts_shalini #shortvideo #ttf',
#   'Tags': ['#kovai360', '#ttf'],
#   'Thumbnail': 'https://i.ytimg.com/vi/uBCY2KG2dQ8/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-06T15:10:53Z',
#   'Duration': 'PT15S',
#   'Views': '292',
#   'Likes': '93',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 's92AXjtju30',
#   'Title': 'amala amu 🌈💕#trending#fanarmy #prank',
#   'Tags': ['#amala',
#    '#whatsappstatus',
#    '#tr8',
#    '#ttf',
#    '#just gallata',
#    '#trendingshorts',
#    '#kovai 360'],
#   'Thumbnail': 'https://i.ytimg.com/vi/s92AXjtju30/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-04T06:53:41Z',
#   'Duration': 'PT9S',
#   'Views': '443',
#   'Likes': '67',
#   'Comments': '3',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'fFWN2WUcLak',
#   'Title': '#fan #short #ttf #shalini',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/fFWN2WUcLak/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-01T09:19:41Z',
#   'Duration': 'PT15S',
#   'Views': '394',
#   'Likes': '78',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'p4oepfa4bpc',
#   'Title': '#fanarmy #instagramyoutube',
#   'Tags': ['#ttf', '#tts_shalini', '#tamilsong', '#trendingshorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/p4oepfa4bpc/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-09-30T02:54:13Z',
#   'Duration': 'PT15S',
#   'Views': '684',
#   'Likes': '156',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '-Ae1VD4LRw0',
#   'Title': '#tts #shalini #ttf',
#   'Tags': ['#ttfpolice', '#trendingshorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/-Ae1VD4LRw0/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-09-28T12:48:47Z',
#   'Duration': 'PT15S',
#   'Views': '822',
#   'Likes': '175',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'DMcCQ86G9yc',
#   'Title': 'semma  action 💞#shortvideo #fanarmy',
#   'Tags': ['#tamilsong', '#trending'],
#   'Thumbnail': 'https://i.ytimg.com/vi/DMcCQ86G9yc/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-09-22T11:09:39Z',
#   'Duration': 'PT8S',
#   'Views': '251',
#   'Likes': '89',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'Q_76HcWNGU0',
#   'Title': 'Happy Birthday To Me 🎂 #tts_shalini/#birthday',
#   'Tags': ['#birthday', '#ttf', '#tamilsong', '#tts_shalini'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Q_76HcWNGU0/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-28T03:49:47Z',
#   'Duration': 'PT1M25S',
#   'Views': '307',
#   'Likes': '50',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '2m9k3fiQKR8',
#   'Title': 'husband and wife comedy shorts #shortvideo #funnyvideo',
#   'Tags': ['#tts_shalini', '#huspand and wife', '#funny'],
#   'Thumbnail': 'https://i.ytimg.com/vi/2m9k3fiQKR8/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-17T13:02:12Z',
#   'Duration': 'PT59S',
#   'Views': '203',
#   'Likes': '56',
#   'Comments': '4',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '_234uADpyuI',
#   'Title': '#tts_shalini army #short #tamilshorts #whatsappstatus',
#   'Tags': ['#whatsappstatus', '#tiktok'],
#   'Thumbnail': 'https://i.ytimg.com/vi/_234uADpyuI/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-14T09:15:02Z',
#   'Duration': 'PT15S',
#   'Views': '397',
#   'Likes': '127',
#   'Comments': '14',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'RKw8Hq6o-m8',
#   'Title': 'Tharamangalam Marriyamman  Festival | Enjoy With My Family | TTS Shalini/@ttsshalini.s',
#   'Tags': ['#youtube',
#    '#trendingshorts',
#    '#trendingvideo',
#    '#ttf',
#    '#tts shalini',
#    '#phone'],
#   'Thumbnail': 'https://i.ytimg.com/vi/RKw8Hq6o-m8/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-12T16:35:59Z',
#   'Duration': 'PT8M22S',
#   'Views': '369',
#   'Likes': '55',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'ccF3J0WZulU',
#   'Title': 'tts shalini oor thiruvila 🤭 #shortvideo #tts_shalini #foryou #trending @ttsshalini.s 💚',
#   'Tags': ['#trendingshorts', '#youtube', '#ttf', '#whatsappstatus'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ccF3J0WZulU/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-11T15:09:52Z',
#   'Duration': 'PT53S',
#   'Views': '281',
#   'Likes': '83',
#   'Comments': '12',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '8TjazwFx4Fg',
#   'Title': 'tts shalini shorts video vidukathai #tts_shalini #tamilsong #trending',
#   'Tags': ['#tamilsong', '#whatsappstatus'],
#   'Thumbnail': 'https://i.ytimg.com/vi/8TjazwFx4Fg/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-10T14:30:22Z',
#   'Duration': 'PT28S',
#   'Views': '535',
#   'Likes': '126',
#   'Comments': '12',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'Jd18lzoCd7g',
#   'Title': 'கிராமத்து விடுகதை #fanarmy #fan #youtubevideo #trendingnow @ttsshalini.s',
#   'Tags': ['#tts_shalini',
#    '#ttf',
#    '#food',
#    '#phone',
#    '#youtube',
#    '#youtubetrending',
#    '#foodchallange'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Jd18lzoCd7g/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-09T02:52:30Z',
#   'Duration': 'PT51S',
#   'Views': '278',
#   'Likes': '91',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'qg4gMRMeW6Y',
#   'Title': 'ஆடி 18  My Village Festival Celebration | Temple Vlog | TTS Shalini @ttsshalini.s',
#   'Tags': ['#trendingshorts',
#    '#trending',
#    '#ttf',
#    '#whatsappstatus',
#    '#tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/qg4gMRMeW6Y/default.jpg',
#   'Description': 'subscribe 💕',
#   'published_Datee': '2022-08-05T15:35:01Z',
#   'Duration': 'PT6M26S',
#   'Views': '243',
#   'Likes': '66',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'RdNMW1qT0Mw',
#   'Title': 'tts shalini mariamman pandigai shorts video #tts_shalini #short #vlog #streetfood',
#   'Tags': ['#streetfood', '#trendingshorts', '#youtube', '#tamilsong', '#ttf'],
#   'Thumbnail': 'https://i.ytimg.com/vi/RdNMW1qT0Mw/default.jpg',
#   'Description': 'subscribe💕@YouTube',
#   'published_Datee': '2022-08-03T14:37:03Z',
#   'Duration': 'PT47S',
#   'Views': '360',
#   'Likes': '104',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'h1Zg6XJhkTY',
#   'Title': 'Insta Reels Slow Motion Making Video | TTs shalini @ttsshalini.s',
#   'Tags': ['#reels',
#    '#trendingshorts',
#    '#ttf',
#    '#amirtha',
#    '#tts shalini',
#    '#tamilsong',
#    '#whatsapp status',
#    '#tamil',
#    '#youtube'],
#   'Thumbnail': 'https://i.ytimg.com/vi/h1Zg6XJhkTY/default.jpg',
#   'Description': 'subscribe 💋',
#   'published_Datee': '2022-08-02T14:22:05Z',
#   'Duration': 'PT1M34S',
#   'Views': '273',
#   'Likes': '64',
#   'Comments': '15',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'YdpTdkR0058',
#   'Title': 'Nee Irukkum Pothu Amma Sentiment | Tamil Album Song Lyrics | TTS Stt #tts_shalini #tts_shalini_army',
#   'Tags': ['#tts_shalini',
#    '#tts_shalini_army',
#    '#tamilsong',
#    '#amma',
#    '#whatsapp status'],
#   'Thumbnail': 'https://i.ytimg.com/vi/YdpTdkR0058/default.jpg',
#   'Description': 'subscribe to all 💕',
#   'published_Datee': '2022-07-30T15:12:35Z',
#   'Duration': 'PT4M38S',
#   'Views': '162',
#   'Likes': '52',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'KpsxEc9z7zY',
#   'Title': 'ஆடி 1 நாம் நாள் #tts_shalini #ttf @ttsshalini.s',
#   'Tags': ['#ttf', '#justicfor', '#trendingshorts', '#reels'],
#   'Thumbnail': 'https://i.ytimg.com/vi/KpsxEc9z7zY/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-18T17:57:34Z',
#   'Duration': 'PT36S',
#   'Views': '328',
#   'Likes': '82',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'PuYHNPXfAzE',
#   'Title': 'tts shalini own video #tts_shalini #foryou #shortvideo @ttsshalini.s',
#   'Tags': ['#duke',
#    '#ktm',
#    '#tts_shalini',
#    '#tamilsong',
#    '#ttf',
#    '#movie',
#    '#trendingshorts',
#    '#youtube'],
#   'Thumbnail': 'https://i.ytimg.com/vi/PuYHNPXfAzE/default.jpg',
#   'Description': '#trendingnow #reels #fanarmy #tts_shalini @ttsshalini.s',
#   'published_Datee': '2022-07-17T08:34:47Z',
#   'Duration': 'PT39S',
#   'Views': '547',
#   'Likes': '100',
#   'Comments': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'EOHks3AujiY',
#   'Title': 'tts shalini shorts video #tts_shalini #short #tamilsong',
#   'Tags': ['#tts_shalini',
#    '#tamilsong',
#    '#trendingshorts',
#    '#trendingshorts',
#    '#reels'],
#   'Thumbnail': 'https://i.ytimg.com/vi/EOHks3AujiY/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-16T07:59:49Z',
#   'Duration': 'PT8S',
#   'Views': '351',
#   'Likes': '121',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'sx4KmcW7CHQ',
#   'Title': 'My Brother Dream Bike Delivery | KTM Duke 200 | TTS Shalini',
#   'Tags': ['#ktmduke',
#    '#ktm',
#    '#ktm WhatsApp status',
#    'how to connect boat earphones via bluetooth',
#    'my mobile number',
#    'tamil spelling',
#    'game game game'],
#   'Thumbnail': 'https://i.ytimg.com/vi/sx4KmcW7CHQ/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-15T11:52:52Z',
#   'Duration': 'PT3M44S',
#   'Views': '134',
#   'Likes': '41',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'jQdTxb25Z_M',
#   'Title': 'My Village Temple Vlog | Village Native Place | TTS Shalini @ttsshalini.s',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/jQdTxb25Z_M/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-11T18:28:06Z',
#   'Duration': 'PT2M52S',
#   'Views': '508',
#   'Likes': '61',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'vuwdkK5YElc',
#   'Title': 'tts shalini shorts video tamil songs #tts_shalini #tamilsong #whatsappstatus @ttsshalini.s',
#   'Tags': ['#whatsapp', '#tamilsong', '#whatsapp status'],
#   'Thumbnail': 'https://i.ytimg.com/vi/vuwdkK5YElc/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-09T16:54:03Z',
#   'Duration': 'PT18S',
#   'Views': '274',
#   'Likes': '66',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'IX6Zug8csqI',
#   'Title': 'TTs_shalini shorts video @ttsshalini.s #reels #tamilsongstatus',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/IX6Zug8csqI/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-07T17:03:03Z',
#   'Duration': 'PT14S',
#   'Views': '247',
#   'Likes': '63',
#   'Comments': '1',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'q1WsyW0qkIM',
#   'Title': 'un samayal arayil shorts video #tts_shalini #tamilsong @ttsshalini.s #foodlover',
#   'Tags': ['#tts_shalini', '#tts shalini WhatsApp status'],
#   'Thumbnail': 'https://i.ytimg.com/vi/q1WsyW0qkIM/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-06T14:50:34Z',
#   'Duration': 'PT15S',
#   'Views': '273',
#   'Likes': '81',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'wqSCErGY0Xo',
#   'Title': 'tts_shalini dialogue shorts video #foryou #tamildialogue #short#fanarmy #folg @ttsshalini.s',
#   'Tags': ['#tts_shalini', '#WhatsApp status'],
#   'Thumbnail': 'https://i.ytimg.com/vi/wqSCErGY0Xo/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-05T18:03:28Z',
#   'Duration': 'PT1M23S',
#   'Views': '105',
#   'Likes': '11',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '1PTTU8Sxu6I',
#   'Title': 'tts_shalini shorts #tts_shalini #tamilshorts @ttsshalini.s #foryou_ #flog #food',
#   'Tags': ['#tts shalini',
#    '#tts shalini tik tok',
#    '#ttts shalini WhatsApp status'],
#   'Thumbnail': 'https://i.ytimg.com/vi/1PTTU8Sxu6I/default.jpg',
#   'Description': '#trendingnow',
#   'published_Datee': '2022-07-05T13:26:02Z',
#   'Duration': 'PT19S',
#   'Views': '308',
#   'Likes': '86',
#   'Comments': '3',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '_PtqGM0D3t0',
#   'Title': 'tts_shalini Nava Palam shorts video #tts_shalini #tamilshorts(@ttsshalini.s',
#   'Tags': ['#volg', '#tts_shalini', '#youtube trending'],
#   'Thumbnail': 'https://i.ytimg.com/vi/_PtqGM0D3t0/default.jpg',
#   'Description': '#tamilsong #tamilratamilra',
#   'published_Datee': '2022-07-04T16:08:42Z',
#   'Duration': 'PT59S',
#   'Views': '270',
#   'Likes': '96',
#   'Comments': '14',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'WGEBkUIMk2Q',
#   'Title': 'Pani Puri Eating Challenge#tts_shalini #fanarmy #short #tamilsong',
#   'Tags': ['#food #food challenge', '#ttf'],
#   'Thumbnail': 'https://i.ytimg.com/vi/WGEBkUIMk2Q/default.jpg',
#   'Description': '#food #foodlover',
#   'published_Datee': '2022-07-02T18:13:14Z',
#   'Duration': 'PT45S',
#   'Views': '119',
#   'Likes': '52',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'VnRjeXlbnco',
#   'Title': 'Pani Puri Eating Challenge | Eating Challenge in TTS Tamilra  | TTS Shalini(@ttsshalini.s',
#   'Tags': ['#food', '#food challenge'],
#   'Thumbnail': 'https://i.ytimg.com/vi/VnRjeXlbnco/default.jpg',
#   'Description': '#food\n#foodchallenge \n#foryou_',
#   'published_Datee': '2022-07-02T08:35:07Z',
#   'Duration': 'PT4M32S',
#   'Views': '563',
#   'Likes': '59',
#   'Comments': '4',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '8GeHrp2DEk8',
#   'Title': 'Chicken Biryani Eating Challenge With My Sister | Food Challenge | TTS Shalini @ttsshalini.s',
#   'Tags': ['#food challenge', '#foos'],
#   'Thumbnail': 'https://i.ytimg.com/vi/8GeHrp2DEk8/default.jpg',
#   'Description': '@ttsshalini.s#food #foodchallenge',
#   'published_Datee': '2022-06-30T12:25:41Z',
#   'Duration': 'PT9M22S',
#   'Views': '227',
#   'Likes': '50',
#   'Comments': '12',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '4X3sDVeSYbk',
#   'Title': 'Ttsshalini live video ❤️|#fanarmy |#tts_shalini |#tamil love sings',
#   'Tags': ['#ttf', '#ttf birthday today', '#ttf live', '#tts_shalini'],
#   'Thumbnail': 'https://i.ytimg.com/vi/4X3sDVeSYbk/default.jpg',
#   'Description': 'subscribe(@ttsshalini.s',
#   'published_Datee': '2022-06-29T18:07:43Z',
#   'Duration': 'PT5M50S',
#   'Views': '92',
#   'Likes': '26',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'EB7wher7ELU',
#   'Title': 'TTs shalini shorts video ❤️#tts_shalini #tamilsong #tamil movie',
#   'Tags': ['#ttf',
#    '#tts_shalini_army',
#    '#tamilsong',
#    '#bomma padam',
#    '#gb whatsapp last seen setting',
#    '#whatsapp problem',
#    '#telegram group link',
#    '#realme phone',
#    'plus two result'],
#   'Thumbnail': 'https://i.ytimg.com/vi/EB7wher7ELU/default.jpg',
#   'Description': '(@ttsshalini.s',
#   'published_Datee': '2022-06-28T18:16:15Z',
#   'Duration': 'PT15S',
#   'Views': '279',
#   'Likes': '102',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'feaxXs8WHTc',
#   'Title': 'TTs_shalini shorts video tamil @ttsshalini.s #short #fanarmy',
#   'Tags': ['#ttf', '#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/feaxXs8WHTc/default.jpg',
#   'Description': '@ttsshalini.s #tts_shalini #ttf #fanarmy',
#   'published_Datee': '2022-06-27T18:54:31Z',
#   'Duration': 'PT7S',
#   'Views': '206',
#   'Likes': '74',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '27N3JzhFfcg',
#   'Title': 'New House For My Grandma | And My Dream Home Construction | TTS Shalini #fanarmy #tts_shalini',
#   'Tags': ['#tts_shalini', '#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/27N3JzhFfcg/default.jpg',
#   'Description': 'subscribe pannuga\n(@ttsshalini.s #foryou_ #tamilsong #tamil',
#   'published_Datee': '2022-06-27T14:32:36Z',
#   'Duration': 'PT4M17S',
#   'Views': '481',
#   'Likes': '56',
#   'Comments': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'nQTJRemF6WA',
#   'Title': '#tts_shalini #foryou #reelsvideo#fanarmy #tts_shalini #short #tamilsong',
#   'Tags': ['#tamilsong', '#pomma padam', '#new'],
#   'Thumbnail': 'https://i.ytimg.com/vi/nQTJRemF6WA/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-26T10:32:45Z',
#   'Duration': 'PT15S',
#   'Views': '201',
#   'Likes': '90',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'egtcXu06548',
#   'Title': 'Hi Friends | Welcome Back to New Vlog | TTS Shalini#fanarmy @ttsshalini.s',
#   'Tags': ['#tamilsong', '#tts_shalini', '#movie'],
#   'Thumbnail': 'https://i.ytimg.com/vi/egtcXu06548/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-26T06:27:18Z',
#   'Duration': 'PT8M12S',
#   'Views': '197',
#   'Likes': '56',
#   'Comments': '11',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '1hCjeL4sm48',
#   'Title': 'tts_shalini shorts video #rashmikamandannadialogue #tts_shalini#short @ttsshalini.s',
#   'Tags': ['#foryou', '#result link 2022'],
#   'Thumbnail': 'https://i.ytimg.com/vi/1hCjeL4sm48/default.jpg',
#   'Description': 'subscribe \n#short #tts_shalini #foryou_ #fanarmy',
#   'published_Datee': '2022-06-25T18:09:19Z',
#   'Duration': 'PT8S',
#   'Views': '255',
#   'Likes': '94',
#   'Comments': '16',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'mSt01AW8Qt0',
#   'Title': 'Yes or No Challenge 😂 #short Video🤣@ttsshalini.s',
#   'Tags': ['#shorts', '#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/mSt01AW8Qt0/default.jpg',
#   'Description': 'SUPPORT pannuga (@ttsshalini.s',
#   'published_Datee': '2022-06-25T06:00:20Z',
#   'Duration': 'PT1M',
#   'Views': '402',
#   'Likes': '112',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'KEZ2byQ5gyU',
#   'Title': '#tts_shalini #shortsvideo',
#   'Tags': ['#trendingshorts',
#    '#11th result',
#    '#result link 2022',
#    '#gb whatsapp last seen setting',
#    '#realme phone'],
#   'Thumbnail': 'https://i.ytimg.com/vi/KEZ2byQ5gyU/default.jpg',
#   'Description': '#short #trendingnow #trendingshorts @ttsshalini.s',
#   'published_Datee': '2022-06-24T13:22:25Z',
#   'Duration': 'PT15S',
#   'Views': '219',
#   'Likes': '113',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'vxsC_gN7RlE',
#   'Title': 'Sorry!! My Last Video🙏🙏 I என்னுடைய கடைசி வீடியோ | TTS Shalini #ttschannel #tts_shalini_army #',
#   'Tags': ['#new',
#    '#thalapathey',
#    '#vijay',
#    '#ajith',
#    '#eating challenge',
#    '#mukbang',
#    '#slime',
#    '#lightroom'],
#   'Thumbnail': 'https://i.ytimg.com/vi/vxsC_gN7RlE/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-22T14:55:50Z',
#   'Duration': 'PT3M3S',
#   'Views': '269',
#   'Likes': '49',
#   'Comments': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'CskSmzf_lwY',
#   'Title': '#tts_shalini_army#short #tts_shalini',
#   'Tags': ['#shorts', '#11th result'],
#   'Thumbnail': 'https://i.ytimg.com/vi/CskSmzf_lwY/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-22T12:11:26Z',
#   'Duration': 'PT15S',
#   'Views': '174',
#   'Likes': '97',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'kLecrkt9HI0',
#   'Title': 'tts_shalini album song #tts_shalini #short #tamilsong #tamilratamilra💕',
#   'Tags': ['#jcb', '#11th result', '#12 result in tamilnadu', '#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/kLecrkt9HI0/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-21T18:01:15Z',
#   'Duration': 'PT15S',
#   'Views': '238',
#   'Likes': '96',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'bwuakhInT04',
#   'Title': 'TTs shalini shorts video ❤️',
#   'Tags': ['#jcb', '#shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/bwuakhInT04/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-21T02:54:38Z',
#   'Duration': 'PT15S',
#   'Views': '153',
#   'Likes': '86',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'sbfOAnwiyZQ',
#   'Title': 'Annaanu  kuptuma #tts_shalini #tamil',
#   'Tags': ['#10result in tamilnadu',
#    '#12resultintamilnadu',
#    '#songs',
#    '#tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/sbfOAnwiyZQ/default.jpg',
#   'Description': '#tts_shalini #tamil#short',
#   'published_Datee': '2022-06-19T18:07:34Z',
#   'Duration': 'PT14S',
#   'Views': '300',
#   'Likes': '99',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'Tai5CxL1rlI',
#   'Title': 'Kutty kutty Lady Album Song Trailer🤙 Tamilra & TTS Shalini army',
#   'Tags': ['#tts shalini album song', 'ALBUM SONG'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Tai5CxL1rlI/default.jpg',
#   'Description': 'subscribe pannuga \n            \n          #short #albumsong #kutty song\n#tts_shalini',
#   'published_Datee': '2022-06-19T09:08:22Z',
#   'Duration': 'PT19S',
#   'Views': '133',
#   'Likes': '28',
#   'Comments': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'BZIuXUfZYuw',
#   'Title': 'Iyanar patha unenapu thanda  shorts video #tts_shalini_army #shorts(@tts_shalini_army',
#   'Tags': ['#dance', '#whatsapp', 'eating show', '#shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/BZIuXUfZYuw/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-19T06:19:58Z',
#   'Duration': 'PT15S',
#   'Views': '174',
#   'Likes': '95',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '1lc0AI-JlZ8',
#   'Title': 'Supermarket Shopping 😘Vlog in Tamil | TTS Shalini army(@ttsshalini.s',
#   'Tags': ['#tts_shalini',
#    '#tamilsong',
#    '#dance',
#    'eating challenge',
#    'eating show',
#    'whatsapp',
#    'maruthani design',
#    '11th result date 2022'],
#   'Thumbnail': 'https://i.ytimg.com/vi/1lc0AI-JlZ8/default.jpg',
#   'Description': 'support\n  be happy\n(@ttsshalini.s \n     \n\n\n\n#tts_shalini\n\n\n\n\n#shorts\n\n\n#vlog',
#   'published_Datee': '2022-06-18T18:22:05Z',
#   'Duration': 'PT3M59S',
#   'Views': '569',
#   'Likes': '49',
#   'Comments': '2',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'QiU6-45fgVo',
#   'Title': '#Husband vs Wife Comedy Alaparaigal 🤣(@ttsshalini.s#short #husband #wife #comedy #foryou_',
#   'Tags': ['#husbantandwife', '#comedytamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/QiU6-45fgVo/default.jpg',
#   'Description': 'subscribe pannuga',
#   'published_Datee': '2022-06-18T10:05:08Z',
#   'Duration': 'PT40S',
#   'Views': '159',
#   'Likes': '80',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'JXiurQjhadI',
#   'Title': 'English spelling 🤣 english thareyathu #short #tts_shalini_army #comedy #foryou(@ttsshalini.s )',
#   'Tags': ['#tamilsong', '#trendingshorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JXiurQjhadI/default.jpg',
#   'Description': 'subscribe pannuga (@ttsshalini.s )\ninsta in\n            tts_shalini_army\n#tamilsong\n#shorts\n#trending\n#viral\n#food\n#jcb video',
#   'published_Datee': '2022-06-17T18:37:16Z',
#   'Duration': 'PT31S',
#   'Views': '2372',
#   'Likes': '235',
#   'Comments': '24',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'EjaFU20XQB8',
#   'Title': 'tts _shalini shorts video|#anne thangachi💖💖(@ttsshalini.s )',
#   'Tags': ['#anne thangachi love',
#    '#whats app status',
#    '#trending',
#    '#shorts',
#    '#viral',
#    '#youtubeshorts',
#    '#amalasaji',
#    '@tts_shalini_army',
#    '#tamil girls reels'],
#   'Thumbnail': 'https://i.ytimg.com/vi/EjaFU20XQB8/default.jpg',
#   'Description': 'subscribe(@ttsshalini.s )#viralshorts \n#trendingshorts #vijaytelevision',
#   'published_Datee': '2022-06-17T09:05:41Z',
#   'Duration': 'PT15S',
#   'Views': '356',
#   'Likes': '104',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'N3FycwG2NGc',
#   'Title': 'Eating 🤣challenge  🤣#short Video🤣@ttsshalini.s',
#   'Tags': ['#tts_shalini',
#    '#tts_shalini_army',
#    '#shorts',
#    '#tamilsongs',
#    '#vijay television',
#    '#vijay tv',
#    '#ttf vasan',
#    '#ttf',
#    '#my self'],
#   'Thumbnail': 'https://i.ytimg.com/vi/N3FycwG2NGc/default.jpg',
#   'Description': 'subscribe (@ttsshalini.s',
#   'published_Datee': '2022-06-17T06:20:04Z',
#   'Duration': 'PT57S',
#   'Views': '211',
#   'Likes': '98',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'XvdDLsgXEJE',
#   'Title': 'tts_shalini shorts😘💕 song video / thereyama unna  ❤#tamilsong #short #reels(@ttsshalini.s',
#   'Tags': ['#tamilsongs', '#(@tts_shalini_army'],
#   'Thumbnail': 'https://i.ytimg.com/vi/XvdDLsgXEJE/default.jpg',
#   'Description': 'support(@ttsshalini.s',
#   'published_Datee': '2022-06-16T18:26:28Z',
#   'Duration': 'PT10S',
#   'Views': '359',
#   'Likes': '136',
#   'Comments': '28',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'U-ukGmw9asM',
#   'Title': '😘Purchasing Gift for My Friend Birthday 💕| Shopping Vlog | TTS Shalini#army  army',
#   'Tags': ['#tts_shalini',
#    '#youtubetrending',
#    '#tamilsong',
#    '#album songs',
#    '#forever',
#    '#vijay television',
#    '#aarif mind voice',
#    '#pandian store',
#    '#vijay tv',
#    '#zee tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/U-ukGmw9asM/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-16T09:29:41Z',
#   'Duration': 'PT3M52S',
#   'Views': '176',
#   'Likes': '52',
#   'Comments': '15',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'Tk9FGURHs3U',
#   'Title': '#tts_shalini shorts video💕tts_shalini_army|#foryou_ #fanarmy #funny video🤣',
#   'Tags': ['#tamilsongs',
#    '#tts_shalini',
#    '#funny videos',
#    '#comedy',
#    '#duke bike',
#    '#tamilshorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Tk9FGURHs3U/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-16T06:18:49Z',
#   'Duration': 'PT30S',
#   'Views': '425',
#   'Likes': '99',
#   'Comments': '20',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'yWq7N8Lj-Ho',
#   'Title': 'tts_shalini_shorts_video_❤️_#tts_shalini_#foryou_#',
#   'Tags': ['#tamilsong',
#    '#reelsinstagram',
#    '#game',
#    '#tts_shalini',
#    '#tts_shalini shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/yWq7N8Lj-Ho/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-15T18:16:33Z',
#   'Duration': 'PT15S',
#   'Views': '137',
#   'Likes': '70',
#   'Comments': '2',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '426k39xf0Ww',
#   'Title': 'likes  paa.....',
#   'Tags': ['#tamilsong', '#tamilshorts', 'funny', '#ammu times', '#comedy'],
#   'Thumbnail': 'https://i.ytimg.com/vi/426k39xf0Ww/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-15T06:29:07Z',
#   'Duration': 'PT15S',
#   'Views': '134',
#   'Likes': '72',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'c7vZpGpV8LI',
#   'Title': 'live video|funny|bloopers🤣',
#   'Tags': ['#myself',
#    '#tamilsongs',
#    '#ammu times',
#    '#tts_shalini',
#    '#tts_shalini shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/c7vZpGpV8LI/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-15T06:04:02Z',
#   'Duration': 'PT6M13S',
#   'Views': '312',
#   'Likes': '83',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'QubLlmm9vbM',
#   'Title': 'tts shalini shorts scenes',
#   'Tags': ['#tamilsongs', '#ammu times', '#newvideotamil', '#comedytamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/QubLlmm9vbM/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-14T18:21:02Z',
#   'Duration': 'PT15S',
#   'Views': '1193',
#   'Likes': '187',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'bjAwdmrvEEw',
#   'Title': 'namma ooru theruvila school luku vara pooran',
#   'Tags': ['#tamilsong', '#comedy', '#tts shalini', '#village'],
#   'Thumbnail': 'https://i.ytimg.com/vi/bjAwdmrvEEw/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-14T10:32:20Z',
#   'Duration': 'PT5M26S',
#   'Views': '558',
#   'Likes': '125',
#   'Comments': '13',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'pp9XxuqpRWE',
#   'Title': '# fan army namma ooru ponnu',
#   'Tags': ['#tamilsong', '#tamil shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/pp9XxuqpRWE/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-14T09:53:55Z',
#   'Duration': 'PT11S',
#   'Views': '373',
#   'Likes': '101',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'XAdTfnSzgOo',
#   'Title': '# fan army',
#   'Tags': ['#tamilsong',
#    '#dukebike',
#    '#dance with Tamil songs',
#    '#tts_shalini',
#    '#tts_shalinishorts',
#    '#short'],
#   'Thumbnail': 'https://i.ytimg.com/vi/XAdTfnSzgOo/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-14T06:29:07Z',
#   'Duration': 'PT15S',
#   'Views': '178',
#   'Likes': '111',
#   'Comments': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'aWikI9yNhv4',
#   'Title': '#fan army',
#   'Tags': ['#tamilsongs', '#songs'],
#   'Thumbnail': 'https://i.ytimg.com/vi/aWikI9yNhv4/default.jpg',
#   'Description': 'support',
#   'published_Datee': '2022-06-13T09:49:26Z',
#   'Duration': 'PT15S',
#   'Views': '208',
#   'Likes': '110',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'r0C1Tk0hpIc',
#   'Title': '# fan army',
#   'Tags': ['#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/r0C1Tk0hpIc/default.jpg',
#   'Description': 'support',
#   'published_Datee': '2022-06-13T06:39:03Z',
#   'Duration': 'PT9S',
#   'Views': '187',
#   'Likes': '85',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '17b7n-YZlNo',
#   'Title': '# fan army',
#   'Tags': ['#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/17b7n-YZlNo/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-13T06:19:07Z',
#   'Duration': 'PT6S',
#   'Views': '2531',
#   'Likes': '221',
#   'Comments': '17',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'iFwUPIxdAok',
#   'Title': '#fanarmy',
#   'Tags': ['#trending', '#trendingnow', '#newvideo', '#shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/iFwUPIxdAok/default.jpg',
#   'Description': 'support',
#   'published_Datee': '2022-06-09T05:41:23Z',
#   'Duration': 'PT13S',
#   'Views': '293',
#   'Likes': '128',
#   'Comments': '16',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'GbW4chZgQPo',
#   'Title': '#fanarmy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/GbW4chZgQPo/default.jpg',
#   'Description': 'support',
#   'published_Datee': '2022-06-08T11:23:53Z',
#   'Duration': 'PT14S',
#   'Views': '209',
#   'Likes': '101',
#   'Comments': '13',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'daLflzYevpI',
#   'Title': '#fanarmy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/daLflzYevpI/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-05-31T09:28:21Z',
#   'Duration': 'PT11S',
#   'Views': '564',
#   'Likes': '168',
#   'Comments': '38',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '4wFVdvDKpkc',
#   'Title': '10000 diamond giveaway',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/4wFVdvDKpkc/default_live.jpg',
#   'Description': '',
#   'published_Datee': '2021-05-24T15:18:39Z',
#   'Duration': 'P0D',
#   'Views': '0',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'}]

# %%
len(video_ids)
# Out:
# 76

# %%
video_details=get_video_info(video_ids)

# %%
video_details
# Out:
# [{'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'EU0apbqE0ZI',
#   'Title': 'couple 🥰shorts video',
#   'Tags': ['#kiss', '#hug', '#tts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/EU0apbqE0ZI/default.jpg',
#   'Description': '',
#   'published_Datee': '2023-04-15T09:53:50Z',
#   'Duration': 'PT11S',
#   'Views': '388',
#   'Likes': '76',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '29_HuFSxDZw',
#   'Title': 'tts_shalini.s 😍😍🥰🥰#whatsappstatus',
#   'Tags': ['#food', '#ttf', '#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/29_HuFSxDZw/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-12-19T11:30:01Z',
#   'Duration': 'PT15S',
#   'Views': '1098',
#   'Likes': '168',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'WNEfiubIoZs',
#   'Title': 'tts_shalini #whatsappstatus #short #foodreview',
#   'Tags': ['#road food', '#road foot', '#streetfood'],
#   'Thumbnail': 'https://i.ytimg.com/vi/WNEfiubIoZs/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-11-20T11:30:08Z',
#   'Duration': 'PT15S',
#   'Views': '936',
#   'Likes': '207',
#   'Comments': '19',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'NJyNgwCWOO8',
#   'Title': '#shalini #shorts💋💚⚡',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/NJyNgwCWOO8/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-11-07T16:58:44Z',
#   'Duration': 'PT15S',
#   'Views': '877',
#   'Likes': '178',
#   'Comments': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '2NP7wOiRF4k',
#   'Title': 'My Favourite Reels Collection like 😍🥰| | TTS Shalini Army #trendingnow',
#   'Tags': ['#tamilsong', '#tts_shalini_army'],
#   'Thumbnail': 'https://i.ytimg.com/vi/2NP7wOiRF4k/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-13T06:14:00Z',
#   'Duration': 'PT4M4S',
#   'Views': '388',
#   'Likes': '94',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '_VyZ7FPm8Ng',
#   'Title': '#instalove #loveit #lovely #mylove #loveher #lovehim #u #ilo tts shalini #gpmuthu #biggbosstamil',
#   'Tags': ['#biggbosstamil', '#ttf', '#gpmuthu', '#comedy'],
#   'Thumbnail': 'https://i.ytimg.com/vi/_VyZ7FPm8Ng/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-10T17:59:21Z',
#   'Duration': 'PT15S',
#   'Views': '384',
#   'Likes': '123',
#   'Comments': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'hjYgAMhppoA',
#   'Title': 'Geetha govindam | Hello Yaru | Geetha 🤨#short | TTS Shalini army#vlog#viral#shorts  #trendingshorts',
#   'Tags': ['#shorts', '#viral', '#viral\n\n#vlog'],
#   'Thumbnail': 'https://i.ytimg.com/vi/hjYgAMhppoA/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-09T15:54:53Z',
#   'Duration': 'PT15S',
#   'Views': '590',
#   'Likes': '113',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'uBCY2KG2dQ8',
#   'Title': 'nee sumara tha irukka in💋💕😁 tts shalini #tts_shalini #shortvideo #ttf',
#   'Tags': ['#kovai360', '#ttf'],
#   'Thumbnail': 'https://i.ytimg.com/vi/uBCY2KG2dQ8/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-06T15:10:53Z',
#   'Duration': 'PT15S',
#   'Views': '292',
#   'Likes': '93',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 's92AXjtju30',
#   'Title': 'amala amu 🌈💕#trending#fanarmy #prank',
#   'Tags': ['#amala',
#    '#whatsappstatus',
#    '#tr8',
#    '#ttf',
#    '#just gallata',
#    '#trendingshorts',
#    '#kovai 360'],
#   'Thumbnail': 'https://i.ytimg.com/vi/s92AXjtju30/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-04T06:53:41Z',
#   'Duration': 'PT9S',
#   'Views': '443',
#   'Likes': '67',
#   'Comments': '3',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'fFWN2WUcLak',
#   'Title': '#fan #short #ttf #shalini',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/fFWN2WUcLak/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-10-01T09:19:41Z',
#   'Duration': 'PT15S',
#   'Views': '394',
#   'Likes': '78',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'p4oepfa4bpc',
#   'Title': '#fanarmy #instagramyoutube',
#   'Tags': ['#ttf', '#tts_shalini', '#tamilsong', '#trendingshorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/p4oepfa4bpc/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-09-30T02:54:13Z',
#   'Duration': 'PT15S',
#   'Views': '684',
#   'Likes': '156',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '-Ae1VD4LRw0',
#   'Title': '#tts #shalini #ttf',
#   'Tags': ['#ttfpolice', '#trendingshorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/-Ae1VD4LRw0/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-09-28T12:48:47Z',
#   'Duration': 'PT15S',
#   'Views': '822',
#   'Likes': '175',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'DMcCQ86G9yc',
#   'Title': 'semma  action 💞#shortvideo #fanarmy',
#   'Tags': ['#tamilsong', '#trending'],
#   'Thumbnail': 'https://i.ytimg.com/vi/DMcCQ86G9yc/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-09-22T11:09:39Z',
#   'Duration': 'PT8S',
#   'Views': '251',
#   'Likes': '89',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'Q_76HcWNGU0',
#   'Title': 'Happy Birthday To Me 🎂 #tts_shalini/#birthday',
#   'Tags': ['#birthday', '#ttf', '#tamilsong', '#tts_shalini'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Q_76HcWNGU0/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-28T03:49:47Z',
#   'Duration': 'PT1M25S',
#   'Views': '307',
#   'Likes': '50',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '2m9k3fiQKR8',
#   'Title': 'husband and wife comedy shorts #shortvideo #funnyvideo',
#   'Tags': ['#tts_shalini', '#huspand and wife', '#funny'],
#   'Thumbnail': 'https://i.ytimg.com/vi/2m9k3fiQKR8/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-17T13:02:12Z',
#   'Duration': 'PT59S',
#   'Views': '203',
#   'Likes': '56',
#   'Comments': '4',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '_234uADpyuI',
#   'Title': '#tts_shalini army #short #tamilshorts #whatsappstatus',
#   'Tags': ['#whatsappstatus', '#tiktok'],
#   'Thumbnail': 'https://i.ytimg.com/vi/_234uADpyuI/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-14T09:15:02Z',
#   'Duration': 'PT15S',
#   'Views': '397',
#   'Likes': '127',
#   'Comments': '14',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'RKw8Hq6o-m8',
#   'Title': 'Tharamangalam Marriyamman  Festival | Enjoy With My Family | TTS Shalini/@ttsshalini.s',
#   'Tags': ['#youtube',
#    '#trendingshorts',
#    '#trendingvideo',
#    '#ttf',
#    '#tts shalini',
#    '#phone'],
#   'Thumbnail': 'https://i.ytimg.com/vi/RKw8Hq6o-m8/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-12T16:35:59Z',
#   'Duration': 'PT8M22S',
#   'Views': '369',
#   'Likes': '55',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'ccF3J0WZulU',
#   'Title': 'tts shalini oor thiruvila 🤭 #shortvideo #tts_shalini #foryou #trending @ttsshalini.s 💚',
#   'Tags': ['#trendingshorts', '#youtube', '#ttf', '#whatsappstatus'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ccF3J0WZulU/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-11T15:09:52Z',
#   'Duration': 'PT53S',
#   'Views': '281',
#   'Likes': '83',
#   'Comments': '12',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '8TjazwFx4Fg',
#   'Title': 'tts shalini shorts video vidukathai #tts_shalini #tamilsong #trending',
#   'Tags': ['#tamilsong', '#whatsappstatus'],
#   'Thumbnail': 'https://i.ytimg.com/vi/8TjazwFx4Fg/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-10T14:30:22Z',
#   'Duration': 'PT28S',
#   'Views': '535',
#   'Likes': '126',
#   'Comments': '12',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'Jd18lzoCd7g',
#   'Title': 'கிராமத்து விடுகதை #fanarmy #fan #youtubevideo #trendingnow @ttsshalini.s',
#   'Tags': ['#tts_shalini',
#    '#ttf',
#    '#food',
#    '#phone',
#    '#youtube',
#    '#youtubetrending',
#    '#foodchallange'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Jd18lzoCd7g/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-08-09T02:52:30Z',
#   'Duration': 'PT51S',
#   'Views': '278',
#   'Likes': '91',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'qg4gMRMeW6Y',
#   'Title': 'ஆடி 18  My Village Festival Celebration | Temple Vlog | TTS Shalini @ttsshalini.s',
#   'Tags': ['#trendingshorts',
#    '#trending',
#    '#ttf',
#    '#whatsappstatus',
#    '#tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/qg4gMRMeW6Y/default.jpg',
#   'Description': 'subscribe 💕',
#   'published_Datee': '2022-08-05T15:35:01Z',
#   'Duration': 'PT6M26S',
#   'Views': '243',
#   'Likes': '66',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'RdNMW1qT0Mw',
#   'Title': 'tts shalini mariamman pandigai shorts video #tts_shalini #short #vlog #streetfood',
#   'Tags': ['#streetfood', '#trendingshorts', '#youtube', '#tamilsong', '#ttf'],
#   'Thumbnail': 'https://i.ytimg.com/vi/RdNMW1qT0Mw/default.jpg',
#   'Description': 'subscribe💕@YouTube',
#   'published_Datee': '2022-08-03T14:37:03Z',
#   'Duration': 'PT47S',
#   'Views': '360',
#   'Likes': '104',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'h1Zg6XJhkTY',
#   'Title': 'Insta Reels Slow Motion Making Video | TTs shalini @ttsshalini.s',
#   'Tags': ['#reels',
#    '#trendingshorts',
#    '#ttf',
#    '#amirtha',
#    '#tts shalini',
#    '#tamilsong',
#    '#whatsapp status',
#    '#tamil',
#    '#youtube'],
#   'Thumbnail': 'https://i.ytimg.com/vi/h1Zg6XJhkTY/default.jpg',
#   'Description': 'subscribe 💋',
#   'published_Datee': '2022-08-02T14:22:05Z',
#   'Duration': 'PT1M34S',
#   'Views': '273',
#   'Likes': '64',
#   'Comments': '15',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'YdpTdkR0058',
#   'Title': 'Nee Irukkum Pothu Amma Sentiment | Tamil Album Song Lyrics | TTS Stt #tts_shalini #tts_shalini_army',
#   'Tags': ['#tts_shalini',
#    '#tts_shalini_army',
#    '#tamilsong',
#    '#amma',
#    '#whatsapp status'],
#   'Thumbnail': 'https://i.ytimg.com/vi/YdpTdkR0058/default.jpg',
#   'Description': 'subscribe to all 💕',
#   'published_Datee': '2022-07-30T15:12:35Z',
#   'Duration': 'PT4M38S',
#   'Views': '162',
#   'Likes': '52',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'KpsxEc9z7zY',
#   'Title': 'ஆடி 1 நாம் நாள் #tts_shalini #ttf @ttsshalini.s',
#   'Tags': ['#ttf', '#justicfor', '#trendingshorts', '#reels'],
#   'Thumbnail': 'https://i.ytimg.com/vi/KpsxEc9z7zY/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-18T17:57:34Z',
#   'Duration': 'PT36S',
#   'Views': '328',
#   'Likes': '82',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'PuYHNPXfAzE',
#   'Title': 'tts shalini own video #tts_shalini #foryou #shortvideo @ttsshalini.s',
#   'Tags': ['#duke',
#    '#ktm',
#    '#tts_shalini',
#    '#tamilsong',
#    '#ttf',
#    '#movie',
#    '#trendingshorts',
#    '#youtube'],
#   'Thumbnail': 'https://i.ytimg.com/vi/PuYHNPXfAzE/default.jpg',
#   'Description': '#trendingnow #reels #fanarmy #tts_shalini @ttsshalini.s',
#   'published_Datee': '2022-07-17T08:34:47Z',
#   'Duration': 'PT39S',
#   'Views': '547',
#   'Likes': '100',
#   'Comments': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'EOHks3AujiY',
#   'Title': 'tts shalini shorts video #tts_shalini #short #tamilsong',
#   'Tags': ['#tts_shalini',
#    '#tamilsong',
#    '#trendingshorts',
#    '#trendingshorts',
#    '#reels'],
#   'Thumbnail': 'https://i.ytimg.com/vi/EOHks3AujiY/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-16T07:59:49Z',
#   'Duration': 'PT8S',
#   'Views': '351',
#   'Likes': '121',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'sx4KmcW7CHQ',
#   'Title': 'My Brother Dream Bike Delivery | KTM Duke 200 | TTS Shalini',
#   'Tags': ['#ktmduke',
#    '#ktm',
#    '#ktm WhatsApp status',
#    'how to connect boat earphones via bluetooth',
#    'my mobile number',
#    'tamil spelling',
#    'game game game'],
#   'Thumbnail': 'https://i.ytimg.com/vi/sx4KmcW7CHQ/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-15T11:52:52Z',
#   'Duration': 'PT3M44S',
#   'Views': '134',
#   'Likes': '41',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'jQdTxb25Z_M',
#   'Title': 'My Village Temple Vlog | Village Native Place | TTS Shalini @ttsshalini.s',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/jQdTxb25Z_M/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-11T18:28:06Z',
#   'Duration': 'PT2M52S',
#   'Views': '508',
#   'Likes': '61',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'vuwdkK5YElc',
#   'Title': 'tts shalini shorts video tamil songs #tts_shalini #tamilsong #whatsappstatus @ttsshalini.s',
#   'Tags': ['#whatsapp', '#tamilsong', '#whatsapp status'],
#   'Thumbnail': 'https://i.ytimg.com/vi/vuwdkK5YElc/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-09T16:54:03Z',
#   'Duration': 'PT18S',
#   'Views': '274',
#   'Likes': '66',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'IX6Zug8csqI',
#   'Title': 'TTs_shalini shorts video @ttsshalini.s #reels #tamilsongstatus',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/IX6Zug8csqI/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-07T17:03:03Z',
#   'Duration': 'PT14S',
#   'Views': '247',
#   'Likes': '63',
#   'Comments': '1',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'q1WsyW0qkIM',
#   'Title': 'un samayal arayil shorts video #tts_shalini #tamilsong @ttsshalini.s #foodlover',
#   'Tags': ['#tts_shalini', '#tts shalini WhatsApp status'],
#   'Thumbnail': 'https://i.ytimg.com/vi/q1WsyW0qkIM/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-06T14:50:34Z',
#   'Duration': 'PT15S',
#   'Views': '273',
#   'Likes': '81',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'wqSCErGY0Xo',
#   'Title': 'tts_shalini dialogue shorts video #foryou #tamildialogue #short#fanarmy #folg @ttsshalini.s',
#   'Tags': ['#tts_shalini', '#WhatsApp status'],
#   'Thumbnail': 'https://i.ytimg.com/vi/wqSCErGY0Xo/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-07-05T18:03:28Z',
#   'Duration': 'PT1M23S',
#   'Views': '105',
#   'Likes': '11',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '1PTTU8Sxu6I',
#   'Title': 'tts_shalini shorts #tts_shalini #tamilshorts @ttsshalini.s #foryou_ #flog #food',
#   'Tags': ['#tts shalini',
#    '#tts shalini tik tok',
#    '#ttts shalini WhatsApp status'],
#   'Thumbnail': 'https://i.ytimg.com/vi/1PTTU8Sxu6I/default.jpg',
#   'Description': '#trendingnow',
#   'published_Datee': '2022-07-05T13:26:02Z',
#   'Duration': 'PT19S',
#   'Views': '308',
#   'Likes': '86',
#   'Comments': '3',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '_PtqGM0D3t0',
#   'Title': 'tts_shalini Nava Palam shorts video #tts_shalini #tamilshorts(@ttsshalini.s',
#   'Tags': ['#volg', '#tts_shalini', '#youtube trending'],
#   'Thumbnail': 'https://i.ytimg.com/vi/_PtqGM0D3t0/default.jpg',
#   'Description': '#tamilsong #tamilratamilra',
#   'published_Datee': '2022-07-04T16:08:42Z',
#   'Duration': 'PT59S',
#   'Views': '270',
#   'Likes': '96',
#   'Comments': '14',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'WGEBkUIMk2Q',
#   'Title': 'Pani Puri Eating Challenge#tts_shalini #fanarmy #short #tamilsong',
#   'Tags': ['#food #food challenge', '#ttf'],
#   'Thumbnail': 'https://i.ytimg.com/vi/WGEBkUIMk2Q/default.jpg',
#   'Description': '#food #foodlover',
#   'published_Datee': '2022-07-02T18:13:14Z',
#   'Duration': 'PT45S',
#   'Views': '119',
#   'Likes': '52',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'VnRjeXlbnco',
#   'Title': 'Pani Puri Eating Challenge | Eating Challenge in TTS Tamilra  | TTS Shalini(@ttsshalini.s',
#   'Tags': ['#food', '#food challenge'],
#   'Thumbnail': 'https://i.ytimg.com/vi/VnRjeXlbnco/default.jpg',
#   'Description': '#food\n#foodchallenge \n#foryou_',
#   'published_Datee': '2022-07-02T08:35:07Z',
#   'Duration': 'PT4M32S',
#   'Views': '563',
#   'Likes': '59',
#   'Comments': '4',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '8GeHrp2DEk8',
#   'Title': 'Chicken Biryani Eating Challenge With My Sister | Food Challenge | TTS Shalini @ttsshalini.s',
#   'Tags': ['#food challenge', '#foos'],
#   'Thumbnail': 'https://i.ytimg.com/vi/8GeHrp2DEk8/default.jpg',
#   'Description': '@ttsshalini.s#food #foodchallenge',
#   'published_Datee': '2022-06-30T12:25:41Z',
#   'Duration': 'PT9M22S',
#   'Views': '227',
#   'Likes': '50',
#   'Comments': '12',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '4X3sDVeSYbk',
#   'Title': 'Ttsshalini live video ❤️|#fanarmy |#tts_shalini |#tamil love sings',
#   'Tags': ['#ttf', '#ttf birthday today', '#ttf live', '#tts_shalini'],
#   'Thumbnail': 'https://i.ytimg.com/vi/4X3sDVeSYbk/default.jpg',
#   'Description': 'subscribe(@ttsshalini.s',
#   'published_Datee': '2022-06-29T18:07:43Z',
#   'Duration': 'PT5M50S',
#   'Views': '92',
#   'Likes': '26',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'EB7wher7ELU',
#   'Title': 'TTs shalini shorts video ❤️#tts_shalini #tamilsong #tamil movie',
#   'Tags': ['#ttf',
#    '#tts_shalini_army',
#    '#tamilsong',
#    '#bomma padam',
#    '#gb whatsapp last seen setting',
#    '#whatsapp problem',
#    '#telegram group link',
#    '#realme phone',
#    'plus two result'],
#   'Thumbnail': 'https://i.ytimg.com/vi/EB7wher7ELU/default.jpg',
#   'Description': '(@ttsshalini.s',
#   'published_Datee': '2022-06-28T18:16:15Z',
#   'Duration': 'PT15S',
#   'Views': '279',
#   'Likes': '102',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'feaxXs8WHTc',
#   'Title': 'TTs_shalini shorts video tamil @ttsshalini.s #short #fanarmy',
#   'Tags': ['#ttf', '#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/feaxXs8WHTc/default.jpg',
#   'Description': '@ttsshalini.s #tts_shalini #ttf #fanarmy',
#   'published_Datee': '2022-06-27T18:54:31Z',
#   'Duration': 'PT7S',
#   'Views': '206',
#   'Likes': '74',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '27N3JzhFfcg',
#   'Title': 'New House For My Grandma | And My Dream Home Construction | TTS Shalini #fanarmy #tts_shalini',
#   'Tags': ['#tts_shalini', '#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/27N3JzhFfcg/default.jpg',
#   'Description': 'subscribe pannuga\n(@ttsshalini.s #foryou_ #tamilsong #tamil',
#   'published_Datee': '2022-06-27T14:32:36Z',
#   'Duration': 'PT4M17S',
#   'Views': '481',
#   'Likes': '56',
#   'Comments': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'nQTJRemF6WA',
#   'Title': '#tts_shalini #foryou #reelsvideo#fanarmy #tts_shalini #short #tamilsong',
#   'Tags': ['#tamilsong', '#pomma padam', '#new'],
#   'Thumbnail': 'https://i.ytimg.com/vi/nQTJRemF6WA/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-26T10:32:45Z',
#   'Duration': 'PT15S',
#   'Views': '201',
#   'Likes': '90',
#   'Comments': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'egtcXu06548',
#   'Title': 'Hi Friends | Welcome Back to New Vlog | TTS Shalini#fanarmy @ttsshalini.s',
#   'Tags': ['#tamilsong', '#tts_shalini', '#movie'],
#   'Thumbnail': 'https://i.ytimg.com/vi/egtcXu06548/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-26T06:27:18Z',
#   'Duration': 'PT8M12S',
#   'Views': '197',
#   'Likes': '56',
#   'Comments': '11',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '1hCjeL4sm48',
#   'Title': 'tts_shalini shorts video #rashmikamandannadialogue #tts_shalini#short @ttsshalini.s',
#   'Tags': ['#foryou', '#result link 2022'],
#   'Thumbnail': 'https://i.ytimg.com/vi/1hCjeL4sm48/default.jpg',
#   'Description': 'subscribe \n#short #tts_shalini #foryou_ #fanarmy',
#   'published_Datee': '2022-06-25T18:09:19Z',
#   'Duration': 'PT8S',
#   'Views': '255',
#   'Likes': '94',
#   'Comments': '16',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'mSt01AW8Qt0',
#   'Title': 'Yes or No Challenge 😂 #short Video🤣@ttsshalini.s',
#   'Tags': ['#shorts', '#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/mSt01AW8Qt0/default.jpg',
#   'Description': 'SUPPORT pannuga (@ttsshalini.s',
#   'published_Datee': '2022-06-25T06:00:20Z',
#   'Duration': 'PT1M',
#   'Views': '402',
#   'Likes': '112',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'KEZ2byQ5gyU',
#   'Title': '#tts_shalini #shortsvideo',
#   'Tags': ['#trendingshorts',
#    '#11th result',
#    '#result link 2022',
#    '#gb whatsapp last seen setting',
#    '#realme phone'],
#   'Thumbnail': 'https://i.ytimg.com/vi/KEZ2byQ5gyU/default.jpg',
#   'Description': '#short #trendingnow #trendingshorts @ttsshalini.s',
#   'published_Datee': '2022-06-24T13:22:25Z',
#   'Duration': 'PT15S',
#   'Views': '219',
#   'Likes': '113',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'vxsC_gN7RlE',
#   'Title': 'Sorry!! My Last Video🙏🙏 I என்னுடைய கடைசி வீடியோ | TTS Shalini #ttschannel #tts_shalini_army #',
#   'Tags': ['#new',
#    '#thalapathey',
#    '#vijay',
#    '#ajith',
#    '#eating challenge',
#    '#mukbang',
#    '#slime',
#    '#lightroom'],
#   'Thumbnail': 'https://i.ytimg.com/vi/vxsC_gN7RlE/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-22T14:55:50Z',
#   'Duration': 'PT3M3S',
#   'Views': '269',
#   'Likes': '49',
#   'Comments': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'CskSmzf_lwY',
#   'Title': '#tts_shalini_army#short #tts_shalini',
#   'Tags': ['#shorts', '#11th result'],
#   'Thumbnail': 'https://i.ytimg.com/vi/CskSmzf_lwY/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-22T12:11:26Z',
#   'Duration': 'PT15S',
#   'Views': '174',
#   'Likes': '97',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'kLecrkt9HI0',
#   'Title': 'tts_shalini album song #tts_shalini #short #tamilsong #tamilratamilra💕',
#   'Tags': ['#jcb', '#11th result', '#12 result in tamilnadu', '#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/kLecrkt9HI0/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-21T18:01:15Z',
#   'Duration': 'PT15S',
#   'Views': '238',
#   'Likes': '96',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'bwuakhInT04',
#   'Title': 'TTs shalini shorts video ❤️',
#   'Tags': ['#jcb', '#shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/bwuakhInT04/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-21T02:54:38Z',
#   'Duration': 'PT15S',
#   'Views': '153',
#   'Likes': '86',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'sbfOAnwiyZQ',
#   'Title': 'Annaanu  kuptuma #tts_shalini #tamil',
#   'Tags': ['#10result in tamilnadu',
#    '#12resultintamilnadu',
#    '#songs',
#    '#tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/sbfOAnwiyZQ/default.jpg',
#   'Description': '#tts_shalini #tamil#short',
#   'published_Datee': '2022-06-19T18:07:34Z',
#   'Duration': 'PT14S',
#   'Views': '300',
#   'Likes': '99',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'Tai5CxL1rlI',
#   'Title': 'Kutty kutty Lady Album Song Trailer🤙 Tamilra & TTS Shalini army',
#   'Tags': ['#tts shalini album song', 'ALBUM SONG'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Tai5CxL1rlI/default.jpg',
#   'Description': 'subscribe pannuga \n            \n          #short #albumsong #kutty song\n#tts_shalini',
#   'published_Datee': '2022-06-19T09:08:22Z',
#   'Duration': 'PT19S',
#   'Views': '133',
#   'Likes': '28',
#   'Comments': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'BZIuXUfZYuw',
#   'Title': 'Iyanar patha unenapu thanda  shorts video #tts_shalini_army #shorts(@tts_shalini_army',
#   'Tags': ['#dance', '#whatsapp', 'eating show', '#shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/BZIuXUfZYuw/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-19T06:19:58Z',
#   'Duration': 'PT15S',
#   'Views': '174',
#   'Likes': '95',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '1lc0AI-JlZ8',
#   'Title': 'Supermarket Shopping 😘Vlog in Tamil | TTS Shalini army(@ttsshalini.s',
#   'Tags': ['#tts_shalini',
#    '#tamilsong',
#    '#dance',
#    'eating challenge',
#    'eating show',
#    'whatsapp',
#    'maruthani design',
#    '11th result date 2022'],
#   'Thumbnail': 'https://i.ytimg.com/vi/1lc0AI-JlZ8/default.jpg',
#   'Description': 'support\n  be happy\n(@ttsshalini.s \n     \n\n\n\n#tts_shalini\n\n\n\n\n#shorts\n\n\n#vlog',
#   'published_Datee': '2022-06-18T18:22:05Z',
#   'Duration': 'PT3M59S',
#   'Views': '569',
#   'Likes': '49',
#   'Comments': '2',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'QiU6-45fgVo',
#   'Title': '#Husband vs Wife Comedy Alaparaigal 🤣(@ttsshalini.s#short #husband #wife #comedy #foryou_',
#   'Tags': ['#husbantandwife', '#comedytamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/QiU6-45fgVo/default.jpg',
#   'Description': 'subscribe pannuga',
#   'published_Datee': '2022-06-18T10:05:08Z',
#   'Duration': 'PT40S',
#   'Views': '159',
#   'Likes': '80',
#   'Comments': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'JXiurQjhadI',
#   'Title': 'English spelling 🤣 english thareyathu #short #tts_shalini_army #comedy #foryou(@ttsshalini.s )',
#   'Tags': ['#tamilsong', '#trendingshorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JXiurQjhadI/default.jpg',
#   'Description': 'subscribe pannuga (@ttsshalini.s )\ninsta in\n            tts_shalini_army\n#tamilsong\n#shorts\n#trending\n#viral\n#food\n#jcb video',
#   'published_Datee': '2022-06-17T18:37:16Z',
#   'Duration': 'PT31S',
#   'Views': '2372',
#   'Likes': '235',
#   'Comments': '24',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'EjaFU20XQB8',
#   'Title': 'tts _shalini shorts video|#anne thangachi💖💖(@ttsshalini.s )',
#   'Tags': ['#anne thangachi love',
#    '#whats app status',
#    '#trending',
#    '#shorts',
#    '#viral',
#    '#youtubeshorts',
#    '#amalasaji',
#    '@tts_shalini_army',
#    '#tamil girls reels'],
#   'Thumbnail': 'https://i.ytimg.com/vi/EjaFU20XQB8/default.jpg',
#   'Description': 'subscribe(@ttsshalini.s )#viralshorts \n#trendingshorts #vijaytelevision',
#   'published_Datee': '2022-06-17T09:05:41Z',
#   'Duration': 'PT15S',
#   'Views': '356',
#   'Likes': '104',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'N3FycwG2NGc',
#   'Title': 'Eating 🤣challenge  🤣#short Video🤣@ttsshalini.s',
#   'Tags': ['#tts_shalini',
#    '#tts_shalini_army',
#    '#shorts',
#    '#tamilsongs',
#    '#vijay television',
#    '#vijay tv',
#    '#ttf vasan',
#    '#ttf',
#    '#my self'],
#   'Thumbnail': 'https://i.ytimg.com/vi/N3FycwG2NGc/default.jpg',
#   'Description': 'subscribe (@ttsshalini.s',
#   'published_Datee': '2022-06-17T06:20:04Z',
#   'Duration': 'PT57S',
#   'Views': '211',
#   'Likes': '98',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'XvdDLsgXEJE',
#   'Title': 'tts_shalini shorts😘💕 song video / thereyama unna  ❤#tamilsong #short #reels(@ttsshalini.s',
#   'Tags': ['#tamilsongs', '#(@tts_shalini_army'],
#   'Thumbnail': 'https://i.ytimg.com/vi/XvdDLsgXEJE/default.jpg',
#   'Description': 'support(@ttsshalini.s',
#   'published_Datee': '2022-06-16T18:26:28Z',
#   'Duration': 'PT10S',
#   'Views': '359',
#   'Likes': '136',
#   'Comments': '28',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'U-ukGmw9asM',
#   'Title': '😘Purchasing Gift for My Friend Birthday 💕| Shopping Vlog | TTS Shalini#army  army',
#   'Tags': ['#tts_shalini',
#    '#youtubetrending',
#    '#tamilsong',
#    '#album songs',
#    '#forever',
#    '#vijay television',
#    '#aarif mind voice',
#    '#pandian store',
#    '#vijay tv',
#    '#zee tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/U-ukGmw9asM/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-16T09:29:41Z',
#   'Duration': 'PT3M52S',
#   'Views': '176',
#   'Likes': '52',
#   'Comments': '15',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'Tk9FGURHs3U',
#   'Title': '#tts_shalini shorts video💕tts_shalini_army|#foryou_ #fanarmy #funny video🤣',
#   'Tags': ['#tamilsongs',
#    '#tts_shalini',
#    '#funny videos',
#    '#comedy',
#    '#duke bike',
#    '#tamilshorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Tk9FGURHs3U/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-16T06:18:49Z',
#   'Duration': 'PT30S',
#   'Views': '425',
#   'Likes': '99',
#   'Comments': '20',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'yWq7N8Lj-Ho',
#   'Title': 'tts_shalini_shorts_video_❤️_#tts_shalini_#foryou_#',
#   'Tags': ['#tamilsong',
#    '#reelsinstagram',
#    '#game',
#    '#tts_shalini',
#    '#tts_shalini shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/yWq7N8Lj-Ho/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-15T18:16:33Z',
#   'Duration': 'PT15S',
#   'Views': '137',
#   'Likes': '70',
#   'Comments': '2',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '426k39xf0Ww',
#   'Title': 'likes  paa.....',
#   'Tags': ['#tamilsong', '#tamilshorts', 'funny', '#ammu times', '#comedy'],
#   'Thumbnail': 'https://i.ytimg.com/vi/426k39xf0Ww/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-15T06:29:07Z',
#   'Duration': 'PT15S',
#   'Views': '134',
#   'Likes': '72',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'c7vZpGpV8LI',
#   'Title': 'live video|funny|bloopers🤣',
#   'Tags': ['#myself',
#    '#tamilsongs',
#    '#ammu times',
#    '#tts_shalini',
#    '#tts_shalini shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/c7vZpGpV8LI/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-15T06:04:02Z',
#   'Duration': 'PT6M13S',
#   'Views': '312',
#   'Likes': '83',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'QubLlmm9vbM',
#   'Title': 'tts shalini shorts scenes',
#   'Tags': ['#tamilsongs', '#ammu times', '#newvideotamil', '#comedytamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/QubLlmm9vbM/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-14T18:21:02Z',
#   'Duration': 'PT15S',
#   'Views': '1193',
#   'Likes': '187',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'bjAwdmrvEEw',
#   'Title': 'namma ooru theruvila school luku vara pooran',
#   'Tags': ['#tamilsong', '#comedy', '#tts shalini', '#village'],
#   'Thumbnail': 'https://i.ytimg.com/vi/bjAwdmrvEEw/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-14T10:32:20Z',
#   'Duration': 'PT5M26S',
#   'Views': '558',
#   'Likes': '125',
#   'Comments': '13',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'pp9XxuqpRWE',
#   'Title': '# fan army namma ooru ponnu',
#   'Tags': ['#tamilsong', '#tamil shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/pp9XxuqpRWE/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-14T09:53:55Z',
#   'Duration': 'PT11S',
#   'Views': '373',
#   'Likes': '101',
#   'Comments': '9',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'XAdTfnSzgOo',
#   'Title': '# fan army',
#   'Tags': ['#tamilsong',
#    '#dukebike',
#    '#dance with Tamil songs',
#    '#tts_shalini',
#    '#tts_shalinishorts',
#    '#short'],
#   'Thumbnail': 'https://i.ytimg.com/vi/XAdTfnSzgOo/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-14T06:29:07Z',
#   'Duration': 'PT15S',
#   'Views': '178',
#   'Likes': '111',
#   'Comments': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'aWikI9yNhv4',
#   'Title': '#fan army',
#   'Tags': ['#tamilsongs', '#songs'],
#   'Thumbnail': 'https://i.ytimg.com/vi/aWikI9yNhv4/default.jpg',
#   'Description': 'support',
#   'published_Datee': '2022-06-13T09:49:26Z',
#   'Duration': 'PT15S',
#   'Views': '208',
#   'Likes': '110',
#   'Comments': '8',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'r0C1Tk0hpIc',
#   'Title': '# fan army',
#   'Tags': ['#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/r0C1Tk0hpIc/default.jpg',
#   'Description': 'support',
#   'published_Datee': '2022-06-13T06:39:03Z',
#   'Duration': 'PT9S',
#   'Views': '187',
#   'Likes': '85',
#   'Comments': '10',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '17b7n-YZlNo',
#   'Title': '# fan army',
#   'Tags': ['#tamilsong'],
#   'Thumbnail': 'https://i.ytimg.com/vi/17b7n-YZlNo/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-06-13T06:19:07Z',
#   'Duration': 'PT6S',
#   'Views': '2531',
#   'Likes': '221',
#   'Comments': '17',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'iFwUPIxdAok',
#   'Title': '#fanarmy',
#   'Tags': ['#trending', '#trendingnow', '#newvideo', '#shorts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/iFwUPIxdAok/default.jpg',
#   'Description': 'support',
#   'published_Datee': '2022-06-09T05:41:23Z',
#   'Duration': 'PT13S',
#   'Views': '293',
#   'Likes': '128',
#   'Comments': '16',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'GbW4chZgQPo',
#   'Title': '#fanarmy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/GbW4chZgQPo/default.jpg',
#   'Description': 'support',
#   'published_Datee': '2022-06-08T11:23:53Z',
#   'Duration': 'PT14S',
#   'Views': '209',
#   'Likes': '101',
#   'Comments': '13',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': 'daLflzYevpI',
#   'Title': '#fanarmy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/daLflzYevpI/default.jpg',
#   'Description': '',
#   'published_Datee': '2022-05-31T09:28:21Z',
#   'Duration': 'PT11S',
#   'Views': '564',
#   'Likes': '168',
#   'Comments': '38',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'channel_Name': 'tts shalini.s',
#   'channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'video_id': '4wFVdvDKpkc',
#   'Title': '10000 diamond giveaway',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/4wFVdvDKpkc/default_live.jpg',
#   'Description': '',
#   'published_Datee': '2021-05-24T15:18:39Z',
#   'Duration': 'P0D',
#   'Views': '0',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'}]

# %%
len(video_details)
# Out:
# 76

# %%
#get comment information
def get_comment_info(video_ids):
  comment_data=[]
  try:
      for video_id in video_ids:
        request=youtube.commentThreads().list(
          part="snippet",
          videoId=video_id,
          maxResults=50
      )
        response=request.execute()
        print(response)

        for item in response['items']:
            data=dict(comment_Id=item['snippet']['topLevelComment']['id'],
                      video_id=item['snippet']['topLevelComment']['snippet']['videoId'],
                      comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                      comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                      comment_published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
            comment_data.append(data)
  except:
      pass
  return  comment_data

# %%
comment_details=get_comment_info(video_ids)
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'oLFFxbU8L2hnuy4D2cnJzdkNtzo', 'pageInfo': {'totalResults': 6, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#commentThread', 'etag': '9RxldSfPupw9HMrXwNYAZUqtT2o', 'id': 'Ugx3dEMIIUQmQmrwUFl4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'EU0apbqE0ZI', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'miXrVNq3gMNPD2tYnsRwDV6HriQ', 'id': 'Ugx3dEMIIUQmQmrwUFl4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'EU0apbqE0ZI', 'textDisplay': 'I  love you', 'textOriginal': 'I  love you', 'authorDisplayName': '@VsuthakarVsuthakar-lm1tt', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kgpoo4vRQWZ7v_XumqsPMaDtrEjVX38RC7dyIMLxuy2D832dS0H_y2mFgsRDNPotjB3w=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@VsuthakarVsuthakar-lm1tt', 'authorChannelId': {'value': 'UCjf2aE7xmrOmRKQo4uEaq2A'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2023-06-07T19:39:24Z', 'updatedAt': '2023-06-07T19:39:24Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'rPRsxMNHCvwpXJuDKHVVgiO_Oyg', 'id': 'Ugz6YcD_FwKeFgWnhgF4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'EU0apbqE0ZI', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'Z6ZzxOI0-z_BvmYdE5pdi7lcmDs', 'id': 'Ugz6YcD_FwKeFgWnhgF4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'EU0apbqE0ZI', 'textDisplay': 'Shalini unnoda lover a.. illa thambi ya', 'textOriginal': 'Shalini unnoda lover a.. illa thambi ya', 'authorDisplayName': '@ragul_iskingmaker', 'authorProfileImageUrl': 'https://yt3.ggpht.com/vgAnb_X2aLsGJRGP9vuPA_gecYdyqmfZVFZILW4CXpLq9Ng2eA8nuWhGOXJ9qMH76EC-mD9m=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@ragul_iskingmaker', 'authorChannelId': {'value': 'UCRwEE4gQSvMSJWD0GyNsMRw'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2023-04-18T08:01:52Z', 'updatedAt': '2023-04-18T08:01:52Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 
...
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'klyWsvjFQVfTAOBKmMuWlpyeuK0', 'pageInfo': {'totalResults': 6, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'fxMbm3NSIjtdqQQ70umHlrypOIk', 'id': 'UgygDAb_nYmKUp_An7R4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'hjYgAMhppoA', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'h2xUobhBtXBVjBdS4REl4D8CCRk', 'id': 'UgygDAb_nYmKUp_An7R4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'hjYgAMhppoA', 'textDisplay': 'Hi', 'textOriginal': 'Hi', 'authorDisplayName': '@dhanadhana9996', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mQEHeFdit8DCqFxmJdNxieUdmln03KSeGvb-KPkxKUOaJ1ItZl4CLGlAugfCE-iXUMWg=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@dhanadhana9996', 'authorChannelId': {'value': 'UCd5Qgt9nqEp6PS5g3QUzdyw'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-11-22T09:43:12Z', 'updatedAt': '2022-11-22T09:43:12Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'a0P4yw2uNI9w42GW0Iba1uirmbw', 'id': 'UgwM50HedMpG3Meedn14AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'hjYgAMhppoA', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'myYUj-rWK5H-niQHxXjMy_dEkY4', 'id': 'UgwM50HedMpG3Meedn14AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'hjYgAMhppoA', 'textDisplay': 'Keetha 😍', 'textOriginal': 'Keetha 😍', 'authorDisplayName': '@dineshrohit8131', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nsY7Wz66Qkthpw8X7S-QjH6rLsZ8W4MCt8yLMHraVlOilDEr_euLO-DWFfReOv4gst5w=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@dineshrohit8131', 'authorChannelId': {'value': 'UCG6tJYby85EL1dWBa4czHnA'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-10-09T16:47:21Z', 'updatedAt': '2022-10-09T16:47:21Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'Mu-LlxOZ4VPB2vyZlIwged7PskA', 'id': 'UgxTMtssXhGtFRdN3Pt4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'hjYgAMhppoA', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'EYKiu4LksFy895NjjL1fSatGh6E', 'id': 'UgxTMtssXhGtFRdN3Pt4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'hjYgAMhppoA', 'textDisplay': '😍😍', 'textOriginal': '😍😍', 'authorDisplayName': '@SivakumarSivakumar-or5ms', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nuNlfceTDiBSTQUhxQ56YDJFbBu1DjRfTpJMFP6ck9D0x3tsglom8eMUA2blBLpRVU8w=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@SivakumarSivakumar-or5ms', 'authorChannelId': {'value': 'UCbuBduPmeUKB8FU0VAeHGGQ'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-10-09T16:41:15Z', 'updatedAt': '2022-10-09T16:41:15Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'zAsD81N98URaU_xWg56CVYHzd-w', 'id': 'UgwZ0PL3vsRCIOfZwkB4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'hjYgAMhppoA', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'mmpYL_0f7ZxTcoYJXcfMc7cX8gk', 'id': 'UgwZ0PL3vsRCIOfZwkB4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'hjYgAMhppoA', 'textDisplay': 'Tts', 'textOriginal': 'Tts', 'authorDisplayName': '@rajrajrajraj755', 'authorProfileImageUrl': 'https://yt3.ggpht.com/4yJoOlPsEixHXXKwApqezbh4qhIUP_vWBz5aw7T42bDker-I3NYWblVRiwrn5LqjHMoLVC_w=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@rajrajrajraj755', 'authorChannelId': {'value': 'UCt0KAI8WVqAq_qvzaiLLqsg'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-10-09T16:13:00Z', 'updatedAt': '2022-10-09T16:13:00Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'aIrGPmX ...

# %%
len(comment_details)
# Out:
# 66

# %%
#get_playlist_details

def get_playlist_details(channel_id):

        next_page_token=None
        All_data=[]
        while True:
                request=youtube.playlists().list(
                        part='snippet,contentDetails',
                        channelId=channel_id,
                        maxResults=50,
                        pageToken=next_page_token
                )
                response=request.execute()

                for item in response['items']:
                        data=dict(playlist_Id=item['id'],
                                Title=item['snippet']['title'],
                                Channel_Id=item['snippet']['channelId'],
                                Channel_Name=item['snippet']['channelTitle'],
                                publishedAt=item['snippet']['publishedAt'],
                                Video_Count=item['contentDetails']['itemCount'])
                        All_data.append(data)
                next_page_token=response.get('nextPageToken')
                if next_page_token is None:
                        break
        return  All_data

# %%
playlist_details=get_playlist_details('UC00qEBA94D-vjRsvX6_EaVQ')

# %%
playlist_details
# Out:
# [{'playlist_Id': 'PLqNw0NjqvCIM6vDqN_G2bNtUAWJAdQI1a',
#   'Title': 'Tts_shalini_army',
#   'Channel_Id': 'UC00qEBA94D-vjRsvX6_EaVQ',
#   'Channel_Name': 'tts shalini.s',
#   'publishedAt': '2022-06-16T18:46:50Z',
#   'Video_Count': 24}]

# %%
#upload to mongoDB

client=pymongo.MongoClient("mongodb+srv://dizosa2112:anthuvan@shalini.q1ctssh.mongodb.net/?retryWrites=true&w=majority&appName=shalini")
db=client["youtube_data"]

# %%
single_channel_detail= []
db=client["youtube_data"]
coll1=db["Channel_details"]
for ch_data in coll1.find({"channel_information.Channel_Name":"Andrew Henry"},{"_id":0}):
    single_channel_detail.append(ch_data["channel_information"])

df_single_channel_detail=pd.DataFrame(single_channel_detail)

# %%
df_single_channel_detail
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def Channel_details(channel_id):
    Ch_details=get_channels_info(channel_id)
    Pl_details=get_playlist_details(channel_id)
    Vi_ids=get_videos_ids(channel_id)
    Vi_details=get_video_info(Vi_ids)
    Com_details=get_comment_info(Vi_ids)

    coll1=db["Channel_details"]
    coll1.insert_one({"channel_information": Ch_details,"playlist_information":Pl_details,
                      "video_information":Vi_details,"comment_information":Com_details})
    return "upload completed successfully"

# %%
#tts shalini:"UC00qEBA94D-vjRsvX6_EaVQ"
#clara kitchen:"UCLKUZXgKWgN7zWuEHrPeYKA"
#:"UC-LsQ1mtWxW1qGrcXhdyQWg"

# %%
insert= Channel_details("UC00qEBA94D-vjRsvX6_EaVQ")
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'oLFFxbU8L2hnuy4D2cnJzdkNtzo', 'pageInfo': {'totalResults': 6, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#commentThread', 'etag': '9RxldSfPupw9HMrXwNYAZUqtT2o', 'id': 'Ugx3dEMIIUQmQmrwUFl4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'EU0apbqE0ZI', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'miXrVNq3gMNPD2tYnsRwDV6HriQ', 'id': 'Ugx3dEMIIUQmQmrwUFl4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'EU0apbqE0ZI', 'textDisplay': 'I  love you', 'textOriginal': 'I  love you', 'authorDisplayName': '@VsuthakarVsuthakar-lm1tt', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kgpoo4vRQWZ7v_XumqsPMaDtrEjVX38RC7dyIMLxuy2D832dS0H_y2mFgsRDNPotjB3w=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@VsuthakarVsuthakar-lm1tt', 'authorChannelId': {'value': 'UCjf2aE7xmrOmRKQo4uEaq2A'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2023-06-07T19:39:24Z', 'updatedAt': '2023-06-07T19:39:24Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'rPRsxMNHCvwpXJuDKHVVgiO_Oyg', 'id': 'Ugz6YcD_FwKeFgWnhgF4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'EU0apbqE0ZI', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'Z6ZzxOI0-z_BvmYdE5pdi7lcmDs', 'id': 'Ugz6YcD_FwKeFgWnhgF4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'EU0apbqE0ZI', 
AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'hjYgAMhppoA', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'mmpYL_0f7ZxTcoYJXcfMc7cX8gk', 'id': 'UgwZ0PL3vsRCIOfZwkB4AaABAg', 'snippet': {'channelId': 'UC00qEBA94D-vjRsvX6_EaVQ', 'videoId': 'hjYgAMhppoA', 'textDisplay': 'Tts', 'textOriginal': 'Tts', 'authorDisplayName': '@rajrajrajraj755', 'authorProfileImageUrl': 'https://yt3.ggpht.com/4yJoOlPsEixHXXKwApqezbh4qhIUP_vWBz5aw7T42bDker-I3NYWblVRiwrn5LqjHMoLVC_w=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@rajrajrajraj755', 'authorChannelId': {'value': 'UCt0KAI8WVqAq_qvzaiLLqsg'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-10-09T16:13:00Z', 'updatedAt': '2022-10-09T16:13:00Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'aIrGPmX ...

# %%
single_playlist_details=[]
db=client["youtube_data"]
coll1=db["Channel_details"]
for ch_data in coll1.find({"channel_information.Channel_Name":"Andrew Henry"},{"_id":0}):
    single_playlist_details.append(ch_data["playlist_information"])

df_single_channel_detail= pd.DataFrame(single_playlist_details)

# %%
df_single_channel_detail
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Table creation for channels,playlists,videos,comments
def channels_table(channel_name_s):
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="anthuvan",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    
    
    create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                            Channel_Id varchar(80) primary key,
                                                            SubscriberCount bigint,
                                                            Views bigint,
                                                            Total_videos int,
                                                            Channal_Description text,
                                                            playlist_Id varchar(80))'''
    cursor.execute( create_query)
    mydb.commit()

        


    single_channel_detail= []
    db=client["youtube_data"]
    coll1=db["Channel_details"]
    for ch_data in coll1.find({"channel_information.Channel_Name":channel_name_s},{"_id":0}):
        single_channel_detail.append(ch_data["channel_information"])

    df_single_channel_detail=pd.DataFrame(single_channel_detail)   


    for index,row in df_single_channel_detail.iterrows():
        insert_query='''insert into channels(Channel_Name,
                                            Channel_Id,
                                            SubscriberCount,
                                            Views,
                                            Total_videos,
                                            Channal_Description,
                                            playlist_Id)
                                         
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['SubscriberCount'],
                row['Views'],
                row['Total_videos'],
                row['Channal_Description'],
                row['Playlist_Id'])
        try:

            cursor.execute(insert_query,values)
            mydb.commit()
        except:

            news= f"Your Provided Channel Name {channel_name_s} is Already Exists"

            return news

# %%
channels_table("tts shalini.s")
# Out:
# 'Your Provided Channel Name tts shalini.s is Already Exists'

# %%
def playlist_table(channel_name_s):
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="anthuvan",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

   
    create_query='''create table if not exists playlists(playlist_Id varchar(100) primary key,
                                                            Title varchar(100),
                                                            Channel_Id varchar(100),
                                                            Channel_Name varchar(100),
                                                            publishedAt timestamp,
                                                            Video_Count int
                                                            )'''
            
        
    cursor.execute(create_query)
    mydb.commit()


    single_playlist_details=[]
    db=client["youtube_data"]
    coll1=db["Channel_details"]
    for ch_data in coll1.find({"channel_information.Channel_Name":"tts shalini.s"},{"_id":0,"playlist_information":1}):
      single_playlist_details.append(ch_data["playlist_information"])

    df_single_channel_detail= pd.DataFrame(single_playlist_details[0])




    for index,row in df_single_channel_detail.iterrows():
                    insert_query='''insert into playlists(playlist_Id,
                                                        Title,
                                                        Channel_Id,
                                                        Channel_Name,
                                                        publishedAt,
                                                        Video_Count
                                                        )

                                                  
                                                
                                                        values(%s,%s,%s,%s,%s,%s)'''
                
                    values=(row['playlist_Id'],
                            row['Title'],
                            row['Channel_Id'],
                            row['Channel_Name'],
                            row['publishedAt'],
                            row['Video_Count']
                            )
                
                    cursor.execute(insert_query,values)
                    mydb.commit()

# %%
playlist_table("tts shalini.s")
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 playlist_table("tts shalini.s")
#
# Cell In[41], line 55, in playlist_table(channel_name_s)
#      35 insert_query='''insert into playlists(playlist_Id,
#      36                                     Title,
#      37                                     Channel_Id,
#    (...)
#      44
#      45                                     values(%s,%s,%s,%s,%s,%s)'''
#      47 values=(row['playlist_Id'],
#      48         row['Title'],
#      49         row['Channel_Id'],
#    (...)
#      52         row['Video_Count']
#      53         )
# ---> 55 cursor.execute(insert_query,values)
#      56 mydb.commit()
#
# UniqueViolation: duplicate key value violates unique constraint "playlists_pkey"
# DETAIL:  Key (playlist_id)=(PLqNw0NjqvCIM6vDqN_G2bNtUAWJAdQI1a) already exists.

# %%
single_videos_details=[]
db=client["youtube_data"]
coll1=db["Channel_details"]
for ch_data in coll1.find({"channel_information.Channel_Name": "tts shalini.s"},{"_id":0}):
 single_videos_details.append(ch_data["video_information"])

df_single_channel_detail= pd.DataFrame(single_videos_details[0])

# %%
df_single_channel_detail
# Out:
#      channel_Name                channel_Id     video_id  \
# 0   tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  EU0apbqE0ZI
# 1   tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  29_HuFSxDZw
# 2   tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  WNEfiubIoZs
# 3   tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  NJyNgwCWOO8
# 4   tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  2NP7wOiRF4k
# ..            ...                       ...          ...
# 71  tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  17b7n-YZlNo
# 72  tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  iFwUPIxdAok
# 73  tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  GbW4chZgQPo
# 74  tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  daLflzYevpI
# 75  tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  4wFVdvDKpkc
#
#                                                 Title  \
# 0                                couple 🥰shorts video
# 1                   tts_shalini.s 😍😍🥰🥰#whatsappstatus
# 2      tts_shalini #whatsappstatus #short #foodreview
# 3                                 #shalini #shorts💋💚⚡
# 4   My Favourite Reels Collection like 😍🥰| | TTS S...
# ..                                                ...
# 71                                         # fan army
# 72                                           #fanarmy
# 73                                           #fanarmy
# 74                                           #fanarmy
# 75                             10000 diamond giveaway
#
#                                              Tags  \
# 0                             [#kiss, #hug, #tts]
# 1                       [#food, #ttf, #tamilsong]
# 2           [#road food, #road foot, #streetfood]
# 3                                            None
# 4                 [#tamilsong, #tts_shalini_army]
# ..                                            ...
# 71                                   [#tamilsong]
# 72  [#trending, #trendingnow, #newvideo, #shorts]
# 73                                           None
# 74                                           None
# 75                                           None
#
#                                             Thumbnail Description  \
# 0      https://i.ytimg.com/vi/EU0apbqE0ZI/default.jpg
# 1      https://i.ytimg.com/vi/29_HuFSxDZw/default.jpg
# 2      https://i.ytimg.com/vi/WNEfiubIoZs/default.jpg
# 3      https://i.ytimg.com/vi/NJyNgwCWOO8/default.jpg
# 4      https://i.ytimg.com/vi/2NP7wOiRF4k/default.jpg
# ..                                                ...         ...
# 71     https://i.ytimg.com/vi/17b7n-YZlNo/default.jpg
# 72     https://i.ytimg.com/vi/iFwUPIxdAok/default.jpg     support
# 73     https://i.ytimg.com/vi/GbW4chZgQPo/default.jpg     support
# 74     https://i.ytimg.com/vi/daLflzYevpI/default.jpg
# 75  https://i.ytimg.com/vi/4wFVdvDKpkc/default_liv...
#
#          published_Datee Duration Views Likes Comments Favorite_Count  \
# 0   2023-04-15T09:53:50Z    PT11S   383    75        6              0
# 1   2022-12-19T11:30:01Z    PT15S  1093   166        9              0
# 2   2022-11-20T11:30:08Z    PT15S   934   206       19              0
# 3   2022-11-07T16:58:44Z    PT15S   872   177       11              0
# 4   2022-10-13T06:14:00Z   PT4M4S   386    94        5              0
# ..                   ...      ...   ...   ...      ...            ...
# 71  2022-06-13T06:19:07Z     PT6S  2531   221       17              0
# 72  2022-06-09T05:41:23Z    PT13S   293   128       16              0
# 73  2022-06-08T11:23:53Z    PT14S   209   101       13              0
# 74  2022-05-31T09:28:21Z    PT11S   564   168       38              0
# 75  2021-05-24T15:18:39Z      P0D     0     2        0              0
#
#    Definition Caption_Status
# 0          hd          false
# 1          hd          false
# 2          hd          false
# 3          hd          false
# 4          sd          false
# ..        ...            ...
# 71         hd          false
# 72         hd          false
# 73         hd          false
# 74         hd          false
# 75         sd          false
#
# [76 rows x 15 columns]

# %%
def videos_table(channel_name_s):
   mydb=psycopg2.connect(host="localhost",
                              user="postgres",
                              password="anthuvan",
                              database="youtube_data",
                              port="5432")
   cursor=mydb.cursor()

   
   create_query='''create table if not exists videos(channel_Name varchar(100),
                                                      Channel_Id varchar(100),
                                                      Video_id varchar(30) primary key,
                                                      Title varchar(150),
                                                      Tags text,
                                                      Thumbnail varchar(100),
                                                      Description text,
                                                      published_Datee timestamp,
                                                      Duration interval,
                                                      Views bigint,
                                                      Likes bigint,
                                                      Comments int,
                                                      Favorite_Count int,
                                                      Definition varchar(10),
                                                      Caption_Status varchar(50)
                                                      )'''
                                             
   cursor.execute(create_query)
   mydb.commit()

   single_videos_details=[]
   db=client["youtube_data"]
   coll1=db["Channel_details"]
   for ch_data in coll1.find({"video_information.channel_Name":"tts shalini.s"},{"_id":0,"video_information":1}):
      single_videos_details.append(ch_data["video_information"])

   df_single_videos_detail= pd.DataFrame(single_videos_details[0])
   
   for index,row in df_single_videos_detail.iterrows():
            insert_query='''insert into videos(channel_Name,
                                                channel_Id,
                                                video_id,
                                                Title,
                                                Tags,
                                                Thumbnail,
                                                Description,
                                                published_Datee,
                                                Duration,
                                                Views,
                                                Likes,
                                                Comments,
                                                Favorite_Count,
                                                Definition,
                                                Caption_Status
                                                )
                                       
                                                values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
            
            values=(row['channel_Name'],
                     row['channel_Id'],
                     row['video_id'],
                     row['Title'],
                     row['Tags'],
                     row['Thumbnail'],
                     row['Description'],
                     row['published_Datee'],
                     row['Duration'],
                     row['Views'],
                     row['Likes'],
                     row['Comments'],
                     row['Favorite_Count'],
                     row['Definition'],
                     row['Caption_Status']
                  )
         
            cursor.execute(insert_query,values)
            mydb.commit()

# %%
videos_table("tts shalini.s")

# %%
single_videos_details=[]
db=client["youtube_data"]
coll1=db["Channel_details"]
for ch_data in coll1.find({"channel_information.Channel_Name": "tts shalini.s"},{"_id":0}):
   single_videos_details.append(ch_data["video_information"])

df = pd.DataFrame(single_videos_details[0])

# %%
df
# Out:
#      channel_Name                channel_Id     video_id  \
# 0   tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  EU0apbqE0ZI
# 1   tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  29_HuFSxDZw
# 2   tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  WNEfiubIoZs
# 3   tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  NJyNgwCWOO8
# 4   tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  2NP7wOiRF4k
# ..            ...                       ...          ...
# 71  tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  17b7n-YZlNo
# 72  tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  iFwUPIxdAok
# 73  tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  GbW4chZgQPo
# 74  tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  daLflzYevpI
# 75  tts shalini.s  UC00qEBA94D-vjRsvX6_EaVQ  4wFVdvDKpkc
#
#                                                 Title  \
# 0                                couple 🥰shorts video
# 1                   tts_shalini.s 😍😍🥰🥰#whatsappstatus
# 2      tts_shalini #whatsappstatus #short #foodreview
# 3                                 #shalini #shorts💋💚⚡
# 4   My Favourite Reels Collection like 😍🥰| | TTS S...
# ..                                                ...
# 71                                         # fan army
# 72                                           #fanarmy
# 73                                           #fanarmy
# 74                                           #fanarmy
# 75                             10000 diamond giveaway
#
#                                              Tags  \
# 0                             [#kiss, #hug, #tts]
# 1                       [#food, #ttf, #tamilsong]
# 2           [#road food, #road foot, #streetfood]
# 3                                            None
# 4                 [#tamilsong, #tts_shalini_army]
# ..                                            ...
# 71                                   [#tamilsong]
# 72  [#trending, #trendingnow, #newvideo, #shorts]
# 73                                           None
# 74                                           None
# 75                                           None
#
#                                             Thumbnail Description  \
# 0      https://i.ytimg.com/vi/EU0apbqE0ZI/default.jpg
# 1      https://i.ytimg.com/vi/29_HuFSxDZw/default.jpg
# 2      https://i.ytimg.com/vi/WNEfiubIoZs/default.jpg
# 3      https://i.ytimg.com/vi/NJyNgwCWOO8/default.jpg
# 4      https://i.ytimg.com/vi/2NP7wOiRF4k/default.jpg
# ..                                                ...         ...
# 71     https://i.ytimg.com/vi/17b7n-YZlNo/default.jpg
# 72     https://i.ytimg.com/vi/iFwUPIxdAok/default.jpg     support
# 73     https://i.ytimg.com/vi/GbW4chZgQPo/default.jpg     support
# 74     https://i.ytimg.com/vi/daLflzYevpI/default.jpg
# 75  https://i.ytimg.com/vi/4wFVdvDKpkc/default_liv...
#
#          published_Datee Duration Views Likes Comments Favorite_Count  \
# 0   2023-04-15T09:53:50Z    PT11S   383    75        6              0
# 1   2022-12-19T11:30:01Z    PT15S  1093   166        9              0
# 2   2022-11-20T11:30:08Z    PT15S   934   206       19              0
# 3   2022-11-07T16:58:44Z    PT15S   872   177       11              0
# 4   2022-10-13T06:14:00Z   PT4M4S   386    94        5              0
# ..                   ...      ...   ...   ...      ...            ...
# 71  2022-06-13T06:19:07Z     PT6S  2531   221       17              0
# 72  2022-06-09T05:41:23Z    PT13S   293   128       16              0
# 73  2022-06-08T11:23:53Z    PT14S   209   101       13              0
# 74  2022-05-31T09:28:21Z    PT11S   564   168       38              0
# 75  2021-05-24T15:18:39Z      P0D     0     2        0              0
#
#    Definition Caption_Status
# 0          hd          false
# 1          hd          false
# 2          hd          false
# 3          hd          false
# 4          sd          false
# ..        ...            ...
# 71         hd          false
# 72         hd          false
# 73         hd          false
# 74         hd          false
# 75         sd          false
#
# [76 rows x 15 columns]

# %%
videos_table("tts shalini.s")
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 videos_table("tts shalini.s")
#
# Cell In[44], line 75, in videos_table(channel_name_s)
#      39 insert_query='''insert into videos(channel_Name,
#      40                                     channel_Id,
#      41                                     video_id,
#    (...)
#      55
#      56                                     values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
#      58 values=(row['channel_Name'],
#      59          row['channel_Id'],
#      60          row['video_id'],
#    (...)
#      72          row['Caption_Status']
#      73       )
# ---> 75 cursor.execute(insert_query,values)
#      76 mydb.commit()
#
# UniqueViolation: duplicate key value violates unique constraint "videos_pkey"
# DETAIL:  Key (video_id)=(EU0apbqE0ZI) already exists.

# %%
single_comments_details=[]
db=client["youtube_data"]
coll1=db["Channel_details"]
for ch_data in coll1.find({"channel_information.Channel_Name": "tts shalini.s"},{"_id":0}):
   single_comments_details.append(ch_data["comment_information"])

df_single_comments_details = pd.DataFrame(single_comments_details[0])

# %%
df_single_comments_details
# Out:
#                     comment_Id     video_id  \
# 0   Ugx3dEMIIUQmQmrwUFl4AaABAg  EU0apbqE0ZI
# 1   Ugz6YcD_FwKeFgWnhgF4AaABAg  EU0apbqE0ZI
# 2   Ugw4jMtm_yg37juzw4R4AaABAg  EU0apbqE0ZI
# 3   UgyHiqdp-hMqYAYBXx14AaABAg  EU0apbqE0ZI
# 4   UgwBhD8lDJ36cthMXWN4AaABAg  EU0apbqE0ZI
# ..                         ...          ...
# 61  UgwM50HedMpG3Meedn14AaABAg  hjYgAMhppoA
# 62  UgxTMtssXhGtFRdN3Pt4AaABAg  hjYgAMhppoA
# 63  UgwZ0PL3vsRCIOfZwkB4AaABAg  hjYgAMhppoA
# 64  Ugwwm7Wisn4w-PE98lh4AaABAg  hjYgAMhppoA
# 65  UgwQTlQ8nZyyk2vUJqd4AaABAg  hjYgAMhppoA
#
#                                comment_Text              comment_Author  \
# 0                               I  love you   @VsuthakarVsuthakar-lm1tt
# 1   Shalini unnoda lover a.. illa thambi ya          @ragul_iskingmaker
# 2                               super super  @manikandansuranthiran1126
# 3                                         ❤                 @alagesh512
# 4                                       🥰🥰🥰                   @msvs5430
# ..                                      ...                         ...
# 61                                 Keetha 😍            @dineshrohit8131
# 62                                       😍😍   @SivakumarSivakumar-or5ms
# 63                                      Tts            @rajrajrajraj755
# 64                           Vera level ma😅           @ManojKumar-kx1sy
# 65                            Super 😉💯💯💯💯🔥🔥           @VijayKumar-sz3sg
#
#        comment_published
# 0   2023-06-07T19:39:24Z
# 1   2023-04-18T08:01:52Z
# 2   2023-04-15T14:28:12Z
# 3   2023-04-15T10:14:39Z
# 4   2023-04-15T10:01:50Z
# ..                   ...
# 61  2022-10-09T16:47:21Z
# 62  2022-10-09T16:41:15Z
# 63  2022-10-09T16:13:00Z
# 64  2022-10-09T16:08:02Z
# 65  2022-10-09T16:08:01Z
#
# [66 rows x 5 columns]

# %%
def comments_table(channels_name_s):
   mydb=psycopg2.connect(host="localhost",
                              user="postgres",
                              password="anthuvan",
                              database="youtube_data",
                              port="5432")
   cursor=mydb.cursor()


   create_query='''create table if not exists comments(comment_Id varchar(100) primary key,
                                                         video_id varchar(50),
                                                         comment_Text text,
                                                         comment_Author varchar(150),
                                                         comment_published timestamp
                                                         )'''
                  
               
   cursor.execute(create_query)
   mydb.commit()


   single_comments_details=[]
   db=client["youtube_data"]
   coll1=db["Channel_details"]
   for ch_data in coll1.find({"comment_information.Channel_Name": channels_name_s},{"_id":0,"comment_information":1}):
      single_comments_details.append(ch_data["comment_information"])

   df_single_comments_details = pd.DataFrame(single_comments_details)

   for index,row in df_single_comments_details.iterrows():
         insert_query='''insert into comments(comment_Id,
                                             video_id,
                                             comment_Text,
                                             comment_Author,
                                             comment_published
                                             )

                                       
                                       values(%s,%s,%s,%s,%s)'''
      
         values=(row['comment_Id'],
                  row['video_id'],
                  row['comment_Text'],
                  row['comment_Author'],
                  row['comment_published']
                  )
               
         cursor.execute(insert_query,values)
         mydb.commit()

# %%
comments_table("tts shalini.s")

# %%
def tables(single_channel):
    news=channels_table(single_channel)
    if news:
        print(news)
    else:
        playlist_table(single_channel)
        videos_table(single_channel)
        comments_table(single_channel)

    return "Tables created successfully"

# %%
Table=tables("UC00qEBA94D-vjRsvX6_EaVQ")
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 Table=tables("UC00qEBA94D-vjRsvX6_EaVQ")
#
# Cell In[54], line 6, in tables(single_channel)
#       4     print(news)
#       5 else:
# ----> 6     playlist_table(single_channel)
#       7     videos_table(single_channel)
#       8     comments_table(single_channel)
#
# Cell In[41], line 55, in playlist_table(channel_name_s)
#      35 insert_query='''insert into playlists(playlist_Id,
#      36                                     Title,
#      37                                     Channel_Id,
#    (...)
#      44
#      45                                     values(%s,%s,%s,%s,%s,%s)'''
#      47 values=(row['playlist_Id'],
#      48         row['Title'],
#      49         row['Channel_Id'],
#    (...)
#      52         row['Video_Count']
#      53         )
# ---> 55 cursor.execute(insert_query,values)
#      56 mydb.commit()
#
# UniqueViolation: duplicate key value violates unique constraint "playlists_pkey"
# DETAIL:  Key (playlist_id)=(PLqNw0NjqvCIM6vDqN_G2bNtUAWJAdQI1a) already exists.

# %%
def show_channels_table():
    ch_list=[]
    db=client["youtube_data"]
    coll1=db["Channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
                ch_list.append(ch_data["channel_information"])
    df=st.dataframe(ch_list)

    return df

# %%
def show_playlist_table():
    pl_list=[]
    db=client["youtube_data"]
    coll1=db["Channel_details"]
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
                        for i in range(len(pl_data["playlist_information"])):
                         pl_list.append(pl_data["playlist_information"][i])

    df1=st.dataframe(pl_list)

    return df1

# %%
def show_videos_table():
    vi_list=[]
    db=client["youtube_data"]
    coll1=db["Channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
                    for i in range(len(vi_data["video_information"])):
                        vi_list.append(vi_data["video_information"][i])

    df2=st.dataframe(vi_list)

    return df2

# %%
def show_comments_table():
   com_list=[]
   db=client["youtube_data"]
   coll1=db["Channel_details"]
   for com_data in coll1.find({},{"_id":0,"comment_information":1}):
                        for i in range(len(com_data["comment_information"])):
                           com_list.append(com_data["comment_information"][i])

   df3=st.dataframe(com_list)

   return df3

# %%
#streamlit part

with st.sidebar:
    st.title(":red[YOUTUBE DATA HAVERSTING AND WAREHOUSING]")
    st.header("Skill Take Away")
    st.caption("Python Scripting")
    st.caption("Data Collection")
    st.caption("MongoDB")
    st.caption("API Integration")
    st.caption("Data Management using MongoDB and Sql")

channel_id=st.text_input("Enter the channet ID")

if st.button("collect and store data"):
    ch_ids=[]
    db=client["Youtube_data"]
    coll1=db["Channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_ids.append(ch_data["channel_information"]["channel_Id"])

    if channel_id in ch_ids:
        st.success("channel Details of the given channel id already exists")
    else:
        insert=Channel_details(channel_id)
        st.success(insert)

if st.button("Migrate to sql"):
    Tables=tables()
    st.success(Tables)
show_table=st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))

if show_table=="CHANNELS":
     show_channels_table()

elif  show_table=="PLAYLISTS":
    show_playlist_table()

elif show_table=="VIDEOS":
    show_videos_table()


elif show_table=="COMMENTS":
    show_comments_table()
# Out:
# 2024-08-12 23:30:34.380
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-08-12 23:30:34.380 Session state does not function when running a script without `streamlit run`

# %%
#sql connection

mydb=psycopg2.connect(host="localhost",
                            user="postgres",
                            password="anthuvan",
                            database="youtube_data",
                            port="5432")
cursor=mydb.cursor()

question=st.selectbox("Select your question",("1. All the videos and the channel name",
                                              "2. channels with most number of videos",
                                              "3. 10 most viewed videos",
                                              "4. comments in each videos",
                                              "5. videos with higest likes",
                                              "6. likes of all videos",
                                              "7. views of each channel",
                                              "8. videos published in the year of 2022",
                                              "9. average duration of all videos in each channel",
                                              "10. videos with highest number of comments"))

if question=="1. All the videos and the channel name":
    query1='''select title as videos,channel_name as channelname from videos'''
    cursor.execute(query1)
    mydb.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1,columns=["video title","channel name"])
    st.write(df)

elif question=="2. channels with most number of videos":
    query2='''select channel_name as channelname,total_videos as no_videos from channels
                order by total_videos desc'''
    cursor.execute(query2)
    mydb.commit()
    t2=cursor.fetchall()
    df2=pd.DataFrame(t2,columns=["channel name","No of videos"])
    st.write(df2)

elif question=="3. 10 most viewed videos":
    query3='''select views as views,channel_name as channelname,title as videotitle from videos
            where views is not null order by views desc limit 10'''
    cursor.execute(query3)
    mydb.commit()
    t3=cursor.fetchall()
    df3=pd.DataFrame(t3,columns=["views","channel name","videotitle"])
    st.write(df3)

elif question=="4. comments in each videos":
    query4='''select comments as no_comments,title as videotitle from videos where comments is not null'''
    cursor.execute(query4) 
    mydb.commit()
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4,columns=["no of comments","videotitle"])
    st.write(df4)

elif question=="5. videos with higest likes":
    query5='''select title as videotitle,channel_name as channelname,likes as likecount
            from videos where likes is not null order by likes desc'''
    cursor.execute(query5) 
    mydb.commit()
    t5=cursor.fetchall()
    df5=pd.DataFrame(t5,columns=["videotitle","channelname","likecount"])
    st.write(df5)

elif question=="6. likes of all videos":
    query6='''select likes as likecount,title as videotitle from videos'''
    cursor.execute(query6) 
    mydb.commit()
    t6=cursor.fetchall()
    df6=pd.DataFrame(t6,columns=["likecount","videostitle"])
    st.write(df6)

elif question=="7. views of each channel":
    query7='''select channel_name as channelname,views as totalviews from channels'''
    cursor.execute(query7) 
    mydb.commit()
    t7=cursor.fetchall()
    df7=pd.DataFrame(t7,columns=["channel name","totalviews"])
    st.write(df7)

elif question=="8. videos published in the year of 2022":
    query8='''select title as video_title,published_datee as videorelease,channel_name as channelname from videos
            where extract(year from published_datee)=2022'''
    cursor.execute(query8) 
    mydb.commit()
    t8=cursor.fetchall()
    df8=pd.DataFrame(t8,columns=["videotitle","published_date","channelname"])
    st.write(df8)

elif question=="9. average duration of all videos in each channel":
    query9='''select channel_name as channelname,AVG(duration)as averageduration from videos group by channel_name'''
    cursor.execute(query9) 
    mydb.commit()
    t9=cursor.fetchall()
    df9=pd.DataFrame(t9,columns=["channelname","averageduration"])
    df9

    T9=[]
    for index,row in df9.iterrows():
        channels_title=row["channelname"]
        average_duration=row["averageduration"]
        average_duration_str=str(average_duration)
        T9.append(dict(channels_title,avgduration=average_duration_str))
    df1=pd.DataFrame(T9)
    st.write(df1)

elif question=="10. videos with highest number of comments":
    query10='''select title as videotitle,channel_name as channelname,comments as comments from videos where comments is
            not null order by comments desc'''
    cursor.execute(query10) 
    mydb.commit()
    t10=cursor.fetchall()
    print(t10)
    df10=pd.DataFrame(t10,columns=["video title","channel name","comments"])
    st.write(df10)
# Out:
# 2024-08-16 20:28:19.998 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2024-08-16 20:28:20.148
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
mydb=psycopg2.connect(host="localhost",
                            user="postgres",
                            password="anthuvan",
                            database="youtube_data",
                            port="5432")
cursor=mydb.cursor()
#elif question=="2. channels with most number of videos":
query2='''select channel_name as channelname,total_videos as no_videos from channels
            order by total_videos desc'''
cursor.execute(query2)
mydb.commit()
t2=cursor.fetchall()
df2=pd.DataFrame(t2,columns=["channel name","No of videos"])
#st.write(df2)
df2
# Out:
#     channel name  No of videos
# 0  tts shalini.s            75
